# %% [markdown]
# # Text Conditioning and Machine Learning
#
# This notebook lays out the process of text analysis and machine learning of scraped Twitter data to identify tweets relevant to humanitarian crises. First labled twitter data collected from previous natural disaters will be cleaned and vectorized. A XXX model will be trained and tweaked over the data. This model will be saved, then applied over tweets from contemporary humanitarian crises to identify emerging disaster hotspots.

# %% [markdown]
# ## Python Packages Used
# This notebook was set up in an environment running Python 3.8 with the following packages:
# pandas, tensorflow, keras, scikit-learn, nltk, gensim

# %%
import os 
import pandas as pd
import collections as col
import pprint
import scipy.sparse as sp
from sklearn.feature_extraction.text import CountVectorizer
from operator import itemgetter
import nltk
import re
import seaborn as sns
import matplotlib.pyplot as plt
import string
import twokenize
from nltk.stem.porter import PorterStemmer
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn import metrics

# %% [markdown]
# ## Preprocessing Script
#
# The following script was adapted from the "preprocessing.py" script avlible from [The CrisisNLP
# /deep-learning-for-big-crisis-data GitHub repository](https://github.com/CrisisNLP/deep-learning-for-big-crisis-data).
#
# The researchers in their paper mentioned getting rid of the urls, digits, and usersnames improved their nlp results.

# %%
################################################################
''' Preporcessing steps: 
1. lowercasing 
2. Digit -> DDD 
3. URLs -> httpAddress 
4. @username -> userID 
5. Remove special characters, keep ; . ! ? 
6. normalize elongation 
7. tokenization using tweetNLP
output is ~/Dropbox (QCRI)/AIDR-DA-ALT-SC/data/labeled datasets/prccd_data/{filename}_AIDR_prccd.csv
'''
#################################################################

#=================
#==> Libraries <==
#=================
import re, os
import string 
import sys
import twokenize
import csv
from collections import defaultdict
from os.path import basename
import ntpath
import codecs
import unicodedata

def process(lst):
    prccd_item_list=[]
    for tweet in lst:


#         # Normalizing utf8 formatting
#         tweet = tweet.decode("unicode-escape").encode("utf8").decode("utf8")
#         #tweet = tweet.encode("utf-8")
#         tweet = tweet.encode("ascii","ignore")
#         tweet = tweet.strip(' \t\n\r')

        # 1. Lowercasing
        tweet = tweet.lower()
        #print "[lowercase]", tweet

        # Word-Level
        tweet = re.sub(' +',' ',tweet) # replace multiple spaces with a single space

        # 2. Normalizing digits
        tweet_words = tweet.strip('\r').split(' ')
        for word in [word for word in tweet_words if word.isdigit()]:
            tweet = tweet.replace(word, "D" * len(word))
#         print( "[digits]", tweet)

        # 3. Normalizing URLs
        tweet_words = tweet.strip('\r').split(' ')
        for word in [word for word in tweet_words if '/' in word or '.' in word and  len(word) > 3]:
            tweet = tweet.replace(word, "")
#         print( "[URLs]", tweet)

        #4. Normalizing username

        tweet_words = tweet.strip('\r').split(' ')
        for word in [word for word in tweet_words if '@' in word]:
            print(word)
            tweet = tweet.replace(word, "")
#         print( "[usrename]", tweet)

#         tweet = tweet
        #4. drop rt tag

        tweet_words = tweet.strip('\r').split(' ')
        for word in [word for word in tweet_words if word == 'rt']:
            print(word)
            tweet = tweet.replace(word, "")
#         print( "[usrename]", tweet)

#         tweet = tweet

        # 5. Removing special Characters
        punc = '@$%^&*()_+-={}[]:"|\'\~`<>/,'
        trans = str.maketrans(punc, ' '*len(punc))
        tweet = tweet.translate(trans)
#         print( "[punc]", tweet)

        # 6. Normalizing +2 elongated char
        tweet = re.sub(r"(.)\1\1+",r'\1\1', tweet)
        #print ("[elong]", tweet)

        # 7. tokenization using tweetNLP
        tweet = ' '.join(twokenize.simpleTokenize(tweet))
        #print( "[token]", tweet )

        #8. fix \n char
        tweet = tweet.replace('\n', ' ')

        prccd_item_list.append(tweet.strip())
#         print ("[processed]", tweet.replace('\n', ' '))
        
    return prccd_item_list

# %%
#nltk.download('all')

# %%
code_dir = os.getcwd()
parent_dir = os.path.dirname(code_dir)
print(parent_dir)
# Out:
# /Volumes/Elements/DataScience/dsa/capstone

# %% [markdown]
# ## [Crisis Benchmark data for training Models](https://crisisnlp.qcri.org/crisis_datasets_benchmarks.html)
#
# <p>The crisis benchmark dataset consists data from several different data sources such as CrisisLex (<a href="http://crisislex.org/data-collections.html#CrisisLexT26" target="_blank">CrisisLex26</a>, <a href="http://crisislex.org/data-collections.html#CrisisLexT6" target="_blank">CrisisLex6</a>), <a href="https://crisisnlp.qcri.org/lrec2016/lrec2016.html" target="_blank">CrisisNLP</a>, <a href="http://mimran.me/papers/imran_shady_carlos_fernando_patrick_practical_2013.pdf" target="_blank">SWDM2013</a>, <a href="http://mimran.me/papers/imran_shady_carlos_fernando_patrick_iscram2013.pdf" target="_blank">ISCRAM13</a>, Disaster Response Data (DRD), <a href="https://data.world/crowdflower/disasters-on-social-media" target="_blank">Disasters on Social Media (DSM)</a>, <a href="https://crisisnlp.qcri.org/crisismmd" target="_blank">CrisisMMD</a> and data from <a href="http://aidr.qcri.org/" target="_blank">AIDR</a>.
# 	  The purpose of this work was to map the class label, remove duplicates and provide a benchmark results for the community. </p>
#
# The authors have their model and data availible on github at <a href="https://github.com/firojalam/crisis_datasets_benchmarks">https://github.com/firojalam/crisis_datasets_benchmarks</a>    </p>
#
# #### Data Availible from: https://crisisnlp.qcri.org/data/crisis_datasets_benchmarks/crisis_datasets_benchmarks_v1.0.tar.gz
# <h4><strong>References</strong></h4>
# <ol>
# <li><a href="http://sites.google.com/site/firojalam/">Firoj Alam</a>, <a href="https://hsajjad.github.io/">Hassan Sajjad</a>, <a href="http://mimran.me/">Muhammad Imran</a> and <a href="https://sites.google.com/site/ferdaofli/">Ferda Ofli</a>, <a href="https://arxiv.org/abs/2004.06774" target="_blank"><strong>CrisisBench: Benchmarking Crisis-related Social Media Datasets for Humanitarian Information Processing,</strong></a> In ICWSM, 2021. [<a href="crisis_dataset_bib1.html">Bibtex</a>]
#         </li>
# <!-- <li><a href="http://sites.google.com/site/firojalam/">Firoj Alam</a>, <a href="https://hsajjad.github.io/">Hassan Sajjad</a>, <a href="http://mimran.me/">Muhammad Imran</a> and <a href="https://sites.google.com/site/ferdaofli/">Ferda Ofli</a>, <a href="https://arxiv.org/abs/2004.06774" target="_blank"><strong>Standardizing and Benchmarking Crisis-related Social Media Datasets for Humanitarian Information Processing,</strong></a> In arxiv, 2020. [<a href="crisis_dataset_bib.html">Bibtex</a>]</li>-->
#         <li>Firoj Alam, Ferda Ofli and Muhammad Imran. CrisisMMD: Multimodal Twitter Datasets from Natural Disasters. In Proceedings of the International AAAI Conference on Web and Social Media (ICWSM), 2018, Stanford, California, USA.</li>
#         <li>Muhammad Imran, Prasenjit Mitra, and Carlos Castillo: Twitter as a Lifeline: Human-annotated Twitter Corpora for NLP of Crisis-related Messages. In Proceedings of the 10th Language Resources and Evaluation Conference (LREC), pp. 1638-1643. May 2016, Portorož, Slovenia.</li>
#         <li>A. Olteanu, S. Vieweg, C. Castillo. 2015. What to Expect When the Unexpected Happens: Social Media Communications Across Crises. In Proceedings of the ACM 2015 Conference on Computer Supported Cooperative Work and Social Computing (CSCW '15). ACM, Vancouver, BC, Canada.</li>
#         <li>A. Olteanu, C. Castillo, F. Diaz, S. Vieweg. 2014. CrisisLex: A Lexicon for Collecting and Filtering Microblogged Communications in Crises. In Proceedings of the AAAI Conference on Weblogs and Social Media (ICWSM'14). AAAI Press, Ann Arbor, MI, USA.</li>
#         <li>Muhammad Imran, Shady Elbassuoni, Carlos Castillo, Fernando Diaz and Patrick Meier. Extracting Information Nuggets from Disaster-Related Messages in Social Media. In Proceedings of the 10th International Conference on Information Systems for Crisis Response and Management (ISCRAM), May 2013, Baden-Baden, Germany.</li>
#         <li>Muhammad Imran, Shady Elbassuoni, Carlos Castillo, Fernando Diaz and Patrick Meier. Practical Extraction of Disaster-Relevant Information from Social Media. In Social Web for Disaster Management (SWDM'13) - Co-located with WWW, May 2013, Rio de Janeiro, Brazil.</li>
#         <li>https://appen.com/datasets/combined- disaster-response-data/</li>
#         <li>https://data.world/crowdflower/disasters- on-social-media</li>

# %% [markdown]
# ### Pull text into notebook and establish variables

# %%
# Set up folders
labled_data_folder  =  os.path.join(parent_dir,"Data/crisis_datasets_benchmarks/all_data_en")
initial_filtering_folder = os.path.join(parent_dir,"Data/crisis_datasets_benchmarks/initial_filtering")

# %%
self_pull_folder = os.path.join(parent_dir,"Data/scraped")

# %%
twts = pd.read_csv(os.path.join(self_pull_folder,"tweets_scraped.csv"), engine='python')
twts = twts.rename(columns={"Text": "text"})

# %%
twts.head()
# Out:
#   ID                   Datetime       TweetId  \
# 0  0  2021-02-19 23:59:59+00:00  1.362915e+18
# 1  1  2021-02-19 23:59:59+00:00  1.362915e+18
# 2  2  2021-02-19 23:59:59+00:00  1.362915e+18
# 3  3  2021-02-19 23:59:59+00:00  1.362915e+18
# 4  4  2021-02-19 23:59:59+00:00  1.362915e+18
#
#                                                 text
# 0                      @storm_ofmylife Vou me dropar
# 1  @DonnaDiva Nothing a couple xans, a few bottle...
# 2  Conditions at 00:00 Gentle Breeze, Dry/Clear \...
# 3  99% of the comments - BTS\n\nanyways, I recomm...
# 4  面白かったしめっちゃきびしかったけどきっとじゅんちゃん相手だともっと優しく教えてるんだろうな...

# %%
# for j, txt in enumerate(twts['text']):
#     print(pd.isna(twts['text'][j]))

# %%
# if pd.isna(twts['text']):
#     print

# %%
# Establish dataframes

train = pd.read_table(os.path.join
                       (labled_data_folder,
                                    "crisis_consolidated_informativeness_filtered_lang_en_train.tsv"))
test = pd.read_table(os.path.join
                       (labled_data_folder,
                                    "crisis_consolidated_informativeness_filtered_lang_en_test.tsv"),
                       sep ='\t', quoting =3)
dev = pd.read_table(os.path.join
                     (labled_data_folder,
                                  "crisis_consolidated_informativeness_filtered_lang_en_dev.tsv"))
combinedf = pd.concat([train,test,dev])

# %%
combinedf.event = combinedf.event.astype('category')
combinedf.class_label =  combinedf.class_label.astype('category')

# %%
combinedf.dtypes
# Out:
# id                int64
# event          category
# source           object
# text             object
# lang             object
# lang_conf       float64
# class_label    category
# dtype: object

# %%
combinedf["event_cat"] = combinedf.event.cat.codes
combinedf["class_label_cat"] = combinedf.class_label.cat.codes
combinedf.head()
# Out:
#                    id                     event                      source  \
# 0                 530           disaster_events  drd-figureeight-multimedia
# 1  913070034204884992           hurricane_maria                   crisismmd
# 2  540027128478044160  2014_philippines_typhoon                crisisnlp-cf
# 3               17711           disaster_events  drd-figureeight-multimedia
# 4           778251007           disaster_events                      dsm-cf
#
#                                                 text lang  lang_conf  \
# 0  Organization that are working in Haiti, I do n...   en   1.000000
# 1  Maria now a hurricane again!! Strong storm sur...   en        NaN
# 2  RT @ANCALERTS: Fallen tree branches scattered ...   en   0.950529
# 3  The Government did not request international a...   en   1.000000
# 4  Remove http://t.co/77b2rNRTt7 Browser Hijacker...   en   1.000000
#
#        class_label  event_cat  class_label_cat
# 0      informative         54                0
# 1      informative         57                0
# 2      informative         47                0
# 3      informative         54                0
# 4  not_informative         54                1

# %%
# df_list = [combinedf,train, test, dev]
# df_list_name = ['combinedf','train', 'test', 'dev']

# %%
combinedf['processed_txt'] = process(combinedf['text'])
# Out:
# @ancalerts:
# @dennis_datu)
# rt
# @newpakistan2020:
# rt
# @ndawsari
# @yemenpeacenews
# @wondering2020
# @k_trolley
# @chase1133
# (@
# @mayortommenino:
# rt
# @michaelbeatty3:
# rt
# @fcbayern
# @greenspansocal
# @mzhemingway:
# rt
# @vijaita:
# @indianexpress
# rt
# @grantjkidney:
# rt
# @hockeyqld
# @arturinabreu:
# @newyorkpost:
# rt
# @unocha_rop
# @wsj
# @yusefforpeace:
# rt
# @therobwest
# @sdesalvo1
# @undertalelou:
# rt
# @noynoyaquino
# @terraceparkelem
# @mjhsconnaughton
# @harrynstuff:
# rt
# @inquisitionnews:
# rt
# @truckerlee3
# @austinmcneill3
# @cabosnews:
# rt
# @thedailybeast:
# (@
# @mckenzie_jenna
# @dior
# @hcalix:
# rt
# @
# @acewzrd_:
# @cnn:
# rt
# @b24fowler
# @abrarulhaqpk:
# rt
# @zamaanie:
# rt
# @csughrue
# @amandabynes
# @stuieboy123
# @zerohunger:
# @un
# rt
# @senbennetco
# rt
# rt
# @atchieescobido
# @xstrology:
# rt
# @bbcbreaking
# @sportsman_25
# @lightningtimes
# @foxandfriends:
# rt
# @etribune
# @maeabi:
# rt
# @foobooz:
# rt
# @cristianinspire
# @paigeloves1d5:
# rt
# @ridhwanazman:
# rt
# @kris_lindemann:
# @pourleternite
# @raymondarroyo:
# ?@mark_shriver
# @savethechildren's
# rt
# @kirainbowmarie
# @uofr
# @gasiaktvu:
# @ktvu
# rt
# @loveiscandy2me:
# rt
# @the
# @rebecca_lammers
# rt@pzfeed
# @jackiezcchn
# @reagan_nation:
# rt
# @piersmorgan
# @inspiredbyiceland
# @ap:
# rt
# @lucyjones
# @time:
# @timeworld)
# rt
# @grahamdelaet
# @niallofficial
# @real_liam_payne
# @cbcalerts:
# rt
# @aususa7
# @neha_aks
# @comubh
# @enerpluscorp
# @kaaaaci
# @theblaze
# rt@heathermla:
# @alhaan_:
# rt
# @teamrunner4life:
# rt
# @breakingnews:
# @nbcnews
# rt
# @tomdonley
# @winecountrydog:
# rt
# @imlisby
# @wsj:
# rt
# @__scrambledeggs
# @danreggie
# @ontariowarnings:
# rt
# @
# @nytimes
# @smusx16475
# @yahoo7
# @
# @brunomars
# @baltcitygis:
# rt
# @weknowwhatsbest:
# rt
# @tanmilso
# @jaredbkeller
# rt
# @cityofcalgary:
# rt
# @rahulkanwal:
# rt
# @stasyszen3
# @ctownhenderson7
# @eighth_oneder:
# @shitdmbfanssay
# rt
# @coryjay34
# @sugaredalomond:
# rt
# @sunkxssedharry
# @xhnews:
# rt
# @youtube
# @
# @
# rt
# @janssen34032875:
# @avakoxxx:
# @realpoxdoc:
# rt
# @flgovscott
# @piersmorgan:
# rt
# @lilliemedia:
# @allaccess
# rt
# @atlwtmgc
# @porceeca
# @news24tvchannel:
# rt
# @hsclarkmystery:
# rt
# @akenjari
# @sonofliberty357
# @naked_virginxo
# @libertarianluke
# @krejcismoxie
# @crystalfoxct
# @4:22
# (@business):\n\nlosses
# @aldjohnmar:
# rt
# @sustainabilitst:
# rt
# ‰ûï@payussfr:
# @migop:
# @flotus
# @potus
# rt
# @theaveragejohn5
# @eddietrunk
# @shinedown's
# @voodoojake
# @markpancratz:
# @foxnews:
# rt
# rt
# @smsupermalls
# @telstra
# u@bigsam101:
# @olayinka321
# @kelseytwn:
# @weat…
# rt
# @drewryniewicz:
# rt
# rt
# @ancalerts:
# rt
# @myraemacdonald:
# @washingtonpost
# rt
# @maithripalas
# @cgoomansingh:
# @globalnational
# rt
# @andersoncooper:
# rt
# @nikkihaley
# @reince
# @gop
# @9newssyd:
# @thetodayshow
# rt
# rt
# @sanjali24:
# @arvindkejriwal
# rt
# @prabalgurung
# @yahoonews
# @paolme:
# rt
# @joan_rivers
# @davidwmwilson:
# @johnspatricc:
# rt
# @smartcares
# @bracefacecam
# @kgbt:
# rt
# @pol_abreu:
# rt
# @jigmeugen
# @karrien80:
# “@accio89:
# rt
# @autistickyuubi:
# rt
# @england498
# @ochaasiapac:
# rt
# @
# @itvnews:
# rt
# @
# @canberratimes:
# rt
# @tonymigliarese
# @cjay92:
# @calgary_news:
# rt
# rt
# @jwarnette:
# rt
# rt
# @eddarrell:
# @wordpre
# rt
# @tanaramclean:
# rt
# @plumberlocal:
# rt
# @revdal
# @danielgoddard
# @jay1972jay
# @luke_brooks
# @darpans:
# rt
# @youtube
# @yusufcatstevens
# @jimpeeps
# @cbcbryan:
# rt
# @brittanyssjoyy:
# rt
# @princeofsydney
# @erummanzoor:
# @asimbajwaispr
# rt
# @wftv
# @scrippsresearch:
# rt
# @youranonnews
# @anonymousfm
# @haaretzcom:
# rt
# @ctvryleecarlson:
# rt
# @konghee:
# rt
# @druhfarrell:
# rt
# @saigebirrell_!
# @topsurveys:
# rt
# @brentmendham
# @pugz_not_drugs
# @gerfingerpoken2
# @robgronkowski:
# rt
# @isseymiyakenyc
# @
# @philippinestar:
# @panahontv
# rt
# @zachkoller_308:
# rt
# @esmeraldajaquez
# @_1boxer
# @progressflorida:
# rt
# @_juicylover
# @democracynow
# @cnnhealth:
# @tsa
# rt
# @dennisdmz:
# rt
# @gregabbott_tx:
# rt
# @
# @yopaulienj
# @verge
# @ishy64:
# @erinedgar:
# @jcsturgeon
# @louis_tomlinson
# @pizzacapers
# married'@foxy__siren:
# @mariomaraczi
# @100prayingwomen:
# @grasswire:
# rt
# @davidrmosley87
# @gccellars
# @great_one_:
# @razarumi:
# @neilbhatiya:
# @razarumi
# rt
# rt
# @sgstudentssay:
# rt
# @hockeygearprobs:
# rt
# @tpeconomy:
# rt
# @staircase2world:
# @real_liam_payne
# rt
# @nwssanjuan
# @altnoaa
# “@wsj:
# @water_agent:
# rt
# @ibatexan:
# @
# rt
# @worldvisioncan
# @drmiguelperales
# @bbc
# @westpacwx
# @djqbert:
# rt
# @vanuatutourism1
# @bob_ritter:
# rt
# ���@the_onlyrex:
# @silent0siris
# @madiserp
# @kibreeze
# @coloradoan:
# rt
# @bbcbreaking:
# rt
# @suryaray
# @juddieedgaf
# @coverdrone:
# rt
# @tashali_little
# @simonw001
# @windspeakernews:
# @nealabarton:
# rt
# @jordyn_wieber:
# rt
# @thekkapoor:
# @juniorbachchan
# @srbachchan
# rt
# @agu_eos
# @prospectparktc
# @therock
# @katewmak:
# rt
# @
# @camilacabello97
# @wsbtv:
# @davidchandley
# rt
# @toddgallant:
# @canadianforces
# rt
# @juliepants501:
# rt
# @ap:
# rt
# @leahhennelphoto:
# rt
# @bigsexymccorkle
# @tastetrekker
# @aaronkatersky:
# @abc
# rt
# @readloveblog:
# rt
# @alarabiya_eng
# @deaconjohnhunt:
# @micheee1020:
# @cardinaltales
# @time:
# @timenewsfeed)
# rt
# @youtube
# @ma3route
# @palomacv
# @bergg69
# @cityofcalgary:
# rt
# @dinkysunflower
# @govph
# @dzbb
# @dzmmteleradyo
# @tat00sh:
# @mike_close:
# rt
# @justin_oakley:
# @danielleoakleyx
# @griffygolf
# @sureshsambandam:
# rt
# @garbuttus
# @davidmdraiman
# @imrichardyap08
# @sgstudentssay:
# rt
# @utsambb:
# @utsawbb!
# rt
# @destructoid
# @curlbox
# @stjude
# @3onyourside
# (@
# @usrealitycheck:
# rt
# @criticalreading:
# rt
# @unfccc:
# @un's
# rt
# @kchenoweth:
# @maddiescorner
# rt
# @heatheryourex:
# rt
# @gcaldwell82
# @rupertmurdochpr:
# rt
# @qldaah:
# @5mileswest
# @7newsmackay:
# rt
# @mclarkhamilton:
# rt
# @kellynbc6
# @renerincon:
# rt
# @whitehouse:
# @govmaryfallin
# rt
# @666potter
# @treasuretoken:
# rt
# @abc
# “@factboook:
# @talathussain12
# @hamidmirgeo
# @omar_quraishi
# @nytimes:
# rt
# @havreeluuuke:
# @sluttyboiichacc
# @
# @jazzzmyn55:
# @tomcatontop
# @the
# @maddijanemusic
# @greenpeace
# @mollymall4
# @ustupidbitch
# @mcasttt
# @drianrok
# @thelaurawright
# @polly_hales
# @choiceznewz:
# @theideafoundry
# rt
# rt
# @solacethewriter
# @edsheeran
# @rhenzramirez18
# @justsammyyg
# @iamchuntian
# @izang_calawita
# @redcross:
# @redcrossokc
# rt
# @akgovbillwalker
# @cowanbrew
# @mountstmary
# @adore_felicia
# @andysamuels31:
# @airjapesfifa
# @jacobyshaddix
# @mvckdaddystackz
# @derekfisher:
# rt
# @cknw:
# rt
# @
# @scgmacgill
# @
# @reeddeming
# ���@ancalerts:
# not@leting
# @cityofnapa
# @sfgate
# @djtyboogie1
# rt
# @melindacalgary
# @daddyreyes6:
# @elliotg78
# @insubcontinent
# @abcnews24:
# rt
# @insidefpl!…
# @carephl
# @discoveryes!
# @youtube
# @romneystormtips:
# rt
# (@
# @drsanjaygupta:
# @daniellecnn!
# rt
# @meena_thiru:
# @m_c_b
# rt
# @realdonaldtrump
# @fema
# @reutersindia:
# rt
# @kwch12:
# rt
# @faizanlakhani:
# rt
# @debraward:
# @rsinghphoto
# @travelodgeca
# rt
# @concernedmom69:
# rt
# @ctvnews:
# rt
# @newyorkstateag
# @boybeliebersoul
# cyclic@ibnlive:
# @nicdasilva:
# @unwomenaust
# rt
# @cnoelkusa:
# rt
# @bigbaby_44
# @theeconomist:
# @codysimpson:
# rt
# @kfcbarstool:
# rt
# @pamduckling
# @frankie0331
# @t0kerfr0g
# @frogsarelovely
# @frogetteca
# @spikedupfrog
# @theswampbog
# @edibletomb:
# rt
# @pawandurani
# @nwsphoenix:
# @sushmaswaraj
# @meaindia
# @pmoindia
# @narendramodi
# @bjprajnathsingh
# @hmoindia
# @adgpi
# @mindbiowingfact:
# rt
# @abcworldnews:
# @jetblue
# rt
# @anilsmsd7:
# rt
# @childs_asia:
# rt
# @dailythunder:
# rt
# @‚ä¶
# @malenaharper:
# rt
# “@x_nataliejade:
# @whysolilmaddie
# @whitehouse:
# rt
# @twcmarkelliot:
# rt
# @lourddv:
# rt
# @mellberr:
# rt
# @rogers_canada,
# @kbtxshel:
# rt
# @michele26152888:
# rt
# @sebheupdate:
# rt
# @shantellexoxo:
# @soulartistic_
# @capmaisonhotel:
# rt
# @crudereporter:
# rt
# @laureledwards66
# @bbcbreaking:
# rt
# @calgaryzoo:
# rt
# @pacisliving:
# rt
# @annecurtissmith
# @danny_xf:
# rt
# @energex
# @moody_d:
# rt
# @dcbiker11
# @katiecouric:
# @kvue
# rt
# @djspinking:
# rt
# @youtube
# @ukti_india
# @mashable:
# rt
# @kanchangupta
# rt
# @trillumanti_nic:
# @brotha_tray:
# rt
# @bbcbreaking:
# rt
# @its_b_bitchhhhh
# @gdacs
# @unocha
# @nasa
# @reach_info
# @morninggloria:
# @gizmodo)
# rt
# @usatoday:
# rt
# @yeh1a
# @convoyofhope
# @arschmitty:
# rt
# @omarsuleiman504:
# rt
# @breaking911:
# rt
# @skaggsjimmy
# @nicollefagan:
# rt
# @ahf_ngo:
# rt
# @
# @cbs11news:
# rt
# @youtube
# ���@cimorelliband:
# @upper
# @pimpdaddyk27:
# @metrocalgary:
# @cityofcalgary
# rt
# @cbcnews
# @paul_dunphy:
# rt
# @littleknits88
# @high_chedd:
# rt
# @gigigraciette:
# @nacioncl
# rt
# @maekaylinghoram
# @wlwt:
# rt
# @infobencana:
# rt
# @archbishopyoung:
# “@tara1029now:
# rt
# @cnnimpact
# @cnnimpact
# @rack__attack
# @jatirado
# @singhnidhiraj
# @gillianfharris:
# rt
# @emergencymgtmag:
# rt
# @rockaway100
# @redcrossny
# @fema
# @ash_eballs69
# @jason_w_white:
# rt
# @10newswtsp
# @xxxkakey:
# @eugenecho:
# @onedayswages
# rt
# @xman813:
# â€œ@nytimes:
# @spinmagazine:
# rt
# @nicknackwalker
# @guntalk:
# rt
# @cnm_jlin_vids:
# rt
# @alipaper:
# @innocent
# @sickipediabot:
# rt
# @n8vdude5
# @jrmccrank
# @worldvisionnews:
# @worldvision
# rt
# rt
# @nikistitz
# @DDD\nall
# @philipduncan
# @cnn:
# rt
# @darrellgambler
# @
# @gabbeedoo
# @zharieyyy
# @mekobien
# @evelynlozada:
# rt
# @youtube
# @612brisbane:
# rt
# @cmofkarnataka:
# rt
# @d_rdaniel:
# rt
# @youngcap513:
# rt
# @rachrudin81:
# @
# @rollingstones
# @cnn
# @dailyhealthtips:
# rt
# @huffingtonpost:
# rt
# @
# @indianexpress
# @rezhasan
# @magnodetri:
# rt
# @httweets:
# rt
# @mgapabebe:
# @missstgstyle
# @medinaann0506
# @jdharm
# @rmlimodriver69
# @howardstern
# @youtube
# @sanjamishra567
# @kidxander
# @harrysbungalow_
# @jamesmennie:
# rt
# @violetsandy2009
# @twhiddleston
# @theelmagoo
# @gopteens
# @foxnews
# @pattonoswalt
# @cbcnews:
# @nbarkakati:
# rt
# @jason_cook:
# @brentzwerneman
# rt
# @ohhayitsdeb:
# rt
# @pnaplan
# @davidmuir
# @asimbajwaispr:
# rt
# (@
# @realcolinquinn:
# rt
# @youranonnews:
# rt
# @ayaztaj1:
# rt
# @gunmouth
# @parrotfishj
# @shainanc
# @rssorg
# @rss_org
# @washingtonpost
# @telstra
# @worldvision
# @youtube
# @team0epiphany
# @brooklyn-battery
# @kitmueller
# @fla_medic:
# rt
# @timesnow:
# rt
# @little_jessie92
# @justinc_philly
# @newwaveoil
# @tsnryanrishaug
# @justjubilee
# @tigerangel2:
# @humanesociety:
# @larimerhumane
# rt
# rt
# @keeefyboy:
# rt
# @richardbranson:
# rt
# @28cgiroux
# rt
# @jianghomeshi:
# rt
# @globalnews:
# rt
# @nbcnewsworld
# @lawsonandy:
# rt
# @momtogeo
# @white
# @jk2012\n\n#riversafari
# @whogivesaknit:
# rt
# @thedailyedge:
# rt
# @kayteekash17
# @justinbieber
# @b_a_a_
# @habitat_org:
# rt
# @ac_in_quest
# @shiwanineupane:
# rt
# @dailycamera:
# rt
# @time:
# rt
# @spreyn0:
# rt
# (@
# @dynah227)
# @louis_tomlinson
# @worldbierhaus:
# rt
# rt“@nytimesscience:
# @houstoniamag:
# rt
# @reuters_co_jp
# @yoshikiofficial
# @gongshowgear:
# rt
# @millajovovich
# @minrvagroup:
# rt
# @willegitimate
# @willb_photos:
# rt
# @shawnmendes
# @katherinedines
# @frankiero
# @moneytreedotcom:
# rt
# @bloombergnews:
# rt
# @telus
# @philredcross:
# @amarkywell
# @ljungstrum:
# rt
# @pjcoyle
# @wsvn
# @rt_com:
# rt
# @etribune:
# rt
# @deadmau5
# @basedbieberlife
# @abscbnnews:
# @gbrofish
# @ibnlive
# @kimplayspokemon
# @
# @mattmarohl:
# rt
# â€œ@esperanzaresort:
# @gpha_philly:
# @sofitelphilly
# rt
# @nkulw
# @recode
# @ndiblasio:
# @usatoday
# rt
# @veteranhank
# @jerrybrowngov
# @shehmirkhanzada:
# @wasayjalil
# @karachiet
# @saqibkz
# rt
# @maciric:
# rt
# @scottyrothnie
# @usnavy
# @pacificcommand
# (@
# @boston_police:
# rt
# @taylorswift13
# @mlb
# “@tyramartinx5:
# @medhatpolice
# @punk_freedom
# @sizzxo
# @dirk_trossen
# @gabethaman:
# @w
# @marykay:
# rt
# @patanjali_yog
# (@
# @iamrachelcrow
# @pdchina:
# rt
# @justin
# @mrdirk49:
# rt
# @lucytobin:
# @_entertain_s:
# rt
# @wlwt:
# rt
# @678resilient:
# rt
# @spulliam:
# @dfwscanner
# rt
# @mobogenie:
# @timesnow
# rt
# @sdbrichards:
# @cbs8
# rt
# @thisisinsider:
# rt
# @_qxvx
# @ckloulou:
# rt
# @sallypancakes
# @the_ashhole:
# rt
# @starxdreamer
# @ashleypurdy
# @telegraph:
# rt
# @alertnet:
# @unfpaasia
# ���@mcs_scb:
# @hayesandrockets
# @nobattlescars
# @teericnsab:
# rt
# @honeydewluke:
# rt
# @cloverstars
# @prasarbharati:
# @pmharper:
# rt
# @stforeigndesk:
# rt
# @likekanyewitans:
# rt
# @og_keyno
# @earls16thave:
# rt
# @rameshnswamy:
# @ndtv
# @ibnlive
# rt
# @fullofbalogna:
# rt
# @caitiebkelly
# @tomstammers
# @thecountnews:
# @thecountnews
# rt
# @chingmachine
# @naturenews
# @ohteenquotes:
# rt
# @
# @livingsocial
# @ac360:
# rt
# @thehill:
# rt
# @yycflood:
# rt
# @moveph
# @adam_jacobi
# @cnnbrk:
# rt
# @newyorker:
# rt
# @nenshi
# @timwilliamscbs:
# @micahgrimes:
# rt
# rt
# @mustbeh4x:
# rt
# @ricknewcombe:
# rt
# @arkansasonline
# @kage_99
# @davidcaramanica
# @imajorrush@djdaveclarke@@greenvelvet_@marcobailey
# @sohailcheemamd:
# rt
# @missdaoh
# @govph:
# rt
# @tomcatarts
# @playskool
# @slizzards96:
# rt
# @suncountry997:
# rt
# @cometakeapuff
# @melloncatis:
# rt
# @damnaarielle
# @kylemacquarrie:
# rt
# @nomee24:
# rt
# @sharoncarpenter:
# rt
# @imth3d3vil
# @robertmarion:
# @ateneodemanilau
# @gretchenho
# @jamesonho
# rt
# @cbs7news:
# rt
# @
# @_newsextra:
# rt
# @texaswomen
# @naomiohreally:
# rt
# @glambadger
# @ricardorossello
# @kingslandlife
# @5sos
# @deadspin:
# rt
# @tweat_itright
# (@
# @real_liam_payne
# @carin_mcleoud
# @
# @greenmonster03:
# rt
# @afrxdiasporaphd:
# rt
# @thinkprogress:
# rt
# @newsokvideo:
# rt
# @miilkkk:
# rt
# @businsmagazine
# @heyyouapp:
# rt
# @travelerschamp:
# rt
# @keisar_:
# rt
# @jawbone:
# rt
# @marbaritaliano
# @daviscup
# @itf_tennis
# @frantastic521
# @christof_moser:
# @guardian
# rt
# @larimersheriff
# @chr3lyc
# @iaff36
# @bernier9
# @postofficenews:
# @postoffice
# rt
# @dost_pagasa:
# rt
# @drdrewhln
# @podcastaddict
# @imperialoil
# @bcantrill:
# rt
# @eoiktmnp:
# rt
# @fema
# rt
# @randomknits
# @gilmae
# ���@gmanews:
# @premier_redford
# @kdoll1234:
# @ur_majestyyy
# @rrobinette999_r
# @inquirerdotnet:
# rt
# @bbcnews
# @onpointdhh
# @jaceyslayer
# @purplegimp:
# rt
# @
# rt
# @dazekaze
# @local_149)
# @arianagrande
# @
# rt
# @imperfxction_:
# rt
# @yahoonews
# @perezhilton:
# rt
# @jsimrock:
# rt
# @simplyerica__
# @emilyraadke
# @yougomarniecoco
# @cassietee_
# @earlystart:
# rt
# @wfp:
# @wfp
# rt
# @pascaljosh:
# rt
# @provchirohealth:
# rt
# @thebestofvines:
# rt
# @osu45804:
# rt
# @nevatrust_again
# @tflanders405:
# rt
# @nytimesworld
# @assouthall
# “@nirvadel:
# @flutrackers:
# @cdcgov
# rt
# @testifra:
# rt
# @
# @djvitognj's
# @ajstream:
# rt
# @riverwoodphoto:
# rt
# @thebaxterbean
# @ryanlanclos:
# rt
# @ausnewsnetwork:
# rt
# @kgoradio:
# rt
# @7newssydney
# @7newssydney
# @mailonline\""
# @kylebakx:
# @cbceyeopener:
# rt
# @polarlon8
# @cokeboys__
# @wunderground:
# @seansublette13:
# rt
# @psteeneagles:
# rt
# @trinacuppett:
# rt
# @scandaloushussy:
# @mediaite
# rt
# @daviidduong
# @priyankac19
# @bkstreetart:
# rt
# @thejoband
# @gimmiewht_iwant:
# rt
# @joelosteen:
# rt
# @kellyoxford:
# rt
# @thebuffalonews:
# rt
# @teslamotorsclub:
# rt
# @jamestwknowles
# rt“@cbsnews:
# @amysohn
# @cnnbrk:
# rt
# @mediatedjustice:
# rt
# @robynbaum
# @jambrewer
# @xoxo_kayanari
# @manny_ottawa:
# @robertfife
# rt
# @ausnewsnetwork
# @breaking
# @ebay
# @breakingstorm:
# @ap
# rt
# @williamshatner
# @hash5wag:
# @davidjneal‚ä¶
# @faroutakhtar:
# rt
# @mybrownnewfies:
# rt
# @mattbarnes010
# @nasa_eo:
# rt
# @aaronpritchett
# @
# @debbieviray
# @andersoncooper
# @grandemarshall
# rt
# @liaqatali2015:
# rt
# @christsavageazz
# @sudarshannewstv
# @8pm
# @mehreenzahra:
# rt
# @tornadotitans:
# rt
# @schamseu:
# @j7mster
# rt
# @aqpk:
# @313syisitak:
# rt
# rt
# @candice_brsd
# @shoyuwt:
# rt
# @bbcbreaking:
# rt
# @sarah4president
# @viviennguyen_
# @echow_
# @dinaa_x33:
# rt
# @andybaldwin:
# @baxterholmes
# @mongabay
# @lvmhprize
# @gmanewsonline
# @unisdr:
# rt
# @neiltyson
# @chat945
# @eurosurveillanc:
# rt
# @keithharkin
# @youtube
# @rt_america:
# rt
# @reutersindia:
# rt
# @
# @asaprockytrill:
# @cdcemergency:
# rt
# @canadiensblog:
# rt
# @weathertrek:
# rt
# @lizzyraps:
# rt
# @undp:
# rt
# @live1dnews:
# rt
# @foxnation:
# rt
# @nymag
# @wacotrib
# @headlinestoday
# @adamyem:
# rt
# @crazykc4
# @sockynoob
# @abc:
# rt
# @derekharmsworth
# @iambyks
# @ralph_nader:
# rt
# @real_serrano:
# @skemer_swagg
# @hai_ren:
# rt
# @buccibrisbane,
# @
# @stcom:
# rt
# @acoyne:
# @tonyherald:
# rt
# @bainjal:
# rt
# “@winashleylynn:
# @vickie627
# @okenergybeat:
# @oneok
# rt
# @
# @metro_nolais:
# rt
# @jordanhembrough
# @
# @
# @nytimes:
# rt
# @andie1743:
# @calgarypolice
# rt
# @ngangadre:
# @ariannatngco:
# rt
# @nytjim:
# @nenshi
# @bittersw33tstar:
# @jayravchan:
# rt
# @britainelects
# @hickscllr
# @gary_lfchandley
# @youranonnews:
# rt
# @orgasmicgomez
# @orgasmicgomez
# @ohyayyyyay
# @survivor_tweet:
# rt
# @cbseveningnews:
# @mike_berlin_
# @vote4terrywong:
# @yycgael
# @calgarydropin
# rt
# @basildudin
# @unicefusa
# @walesger
# @quakestoday:
# rt
# @
# @jessssreyes
# @nbcnightlynews:
# rt
# @presstv
# @alexdunlapnfl:
# @drewtumaabc3:
# rt
# rt
# @nbcnews
# @onurnoyaner:
# rt
# @iiambiboy:
# rt
# @studenttofarm:
# rt
# @greshandzo
# @emergencyvol:
# rt
# @youtube
# @guardian:
# rt
# @dabeard:
# rt
# @pakstatetimes:
# rt
# @crumbalicious
# @zaynhaven:
# rt
# @thesunugurung:
# rt
# @julienlegeard
# @fakejohnruane
# @sunrisesbysandi:
# rt
# @stevelevine:
# @quartz
# rt
# @sgottliebfda:
# @boingboing:
# rt
# @aftershock_delo
# @tricolore_regis
# @theweatherboy:
# rt
# @antduttine:
# @hi_ph
# rt
# @bostondotcom:
# @asiainpictures:
# rt
# @dougmartin17
# @racermag:
# @jack_harvey42
# @indycar
# @wgi
# rt
# @spenniy:
# rt
# @anthony_mundine
# @citizenradio:
# rt
# @triplemsydney:
# @nswpolice
# @salvos
# rt
# @edbott
# @jeremyc_bradley
# @abm_mission:
# @angliall‰û_
# rt
# @thenissonian
# @rejectdcartoons
# @north2north
# @fsdaybreak
# @mannypacquiao
# @miraclady
# rt
# “@gbrunsvold:
# @geetapandeybbc:
# rt
# @cornerstonesc:
# rt
# @ringuette:
# rt
# @simply_adams
# @
# @miafarrow:
# rt
# @louisvilleusace
# @johnes_sam
# @donateaphoto
# seemingly@7news:
# @universalhub
# @sarah_liz98
# @timesnow
# @kittenomelette
# @singmytweetsbro
# @singingjoe20
# @jonathanwillis
# @yycboarder:
# rt
# @gabelandeskog92:
# rt
# @chrisyoungmusic:
# @realalexjones:
# rt
# @ajcalderon
# @thepamela
# @charliekayecbs:
# @cbsnews
# rt
# @saimamohsin
# @fvdlfvdl:
# rt
# @tbbclub
# @samaritanspurse:
# @samaritanspurse
# @spcanada
# @samspurseuk
# rt
# @pakistan_army:
# rt
# @watergatesummer:
# @christinenolfi:
# rt
# @uniwatch:
# rt
# @nickimi57917077
# @ss_serene:
# rt
# @_simplyruthless
# @vm_alto:
# @supercakefyu:
# rt
# rt
# @nealabarton:
# @canadianforces
# rt
# @22_minutes:
# rt
# @hassanrouhani
# rmft@kamthecreator:
# @ruby_reds
# @youralberta:
# @…
# rt
# @weelaura:
# rt
# @redcross
# @annev:
# rt
# @meherzaidi
# @grist
# @nenshi
# @steveaoki:
# rt
# @toddgallant
# @nix_km
# @oathkeepers
# @globalnews:
# rt
# @ruthcabal15:
# @gmanews
# rt
# @taylortoofresh:
# @cdcgov
# (@
# @d_gilmercfre
# @cfcalgary
# @cf_hamilton
# @cfcalgary
# @kcaligari
# @nyc_blonde:
# @yychelps:
# rt
# @txdps:
# @usnwsgov
# rt
# @garethconde
# @sororityproblem:
# @kimkardashian:
# rt
# rt
# @uabearsfootball
# @showme_luv:
# @cnn
# @movesweatlove
# @susanxo_
# @xocristin_a
# @scarletvirgin:
# @paparoxi:
# rt
# @amazinlymika
# @scoopit
# @sedvitae:
# @reliefweb
# rt
# @shesthefirst
# @blinknow
# @annelamott:
# rt
# @
# @nationalpost
# @opengoodhacks
# @dominiloka
# @
# @sqrtmusik
# @andreas_juul:
# rt
# @truthaboutkerry
# @amyjomartin:
# @yahoo
# rt
# [@reuters
# @alexiskwpceo:
# @yourstruely_kat
# @
# @wxchris2011:
# rt
# @pib_india:
# rt
# @bbcbreaking:
# rt
# @feedthechildren:
# rt
# @brodyfrieling
# @hanna_brooksie
# @whitehouse
# @spokespersonmod:
# rt
# @jgrivel:
# rt
# @globalcalgary:
# rt
# @a2msays:
# rt
# @ontariowarnings:
# @senatemajldr
# @shypullum15
# @davidwood90:
# rt
# @joshabbottband:
# rt
# @_callieosborne:
# @askmrjay:
# rt
# @inmoxiecated
# rt
# ãƒâ¤ãƒâ³ãƒâ¬@nytmetro:
# @librab103:
# rt
# @sportscenter:
# rt
# @fcn2go
# @theusnewz:
# rt
# @profiletree
# @kettlebellking
# @unicef
# @campbelllivenz
# @pgatourcanada:
# rt
# @ynb2210
# @mattspelman
# @racejoy
# @suffolkmarathon
# @ptvph:
# rt
# @mistydedwards
# @lnyourthoughts:
# @feednyc:
# rt
# @usgs)
# (@
# @danielledeniese:
# rt
# @ashton5sos
# @thathugdealer:
# rt
# @mixfmtucson:
# rt
# @kris6news:
# rt
# @rab_59:
# rt
# @sebastianiwines:
# rt
# @geektyrant:
# @elijahreyes
# @geektyrant
# @awais_niazi1:
# @isfpakistan
# rt
# @zacefron:
# rt
# @jackmulholland1
# @gma:
# rt
# @sweetexoticlove
# @cnbcpakistan:
# rt
# @ruislipr
# @forbes:
# rt
# @stephennolan:
# rt
# @gma:
# @abcnewsradio:
# rt
# rt
# @daleloberger:
# rt
# @kernelbrewery
# @alvinnebeer
# @slimthugga__
# @dis_be_me104
# '@wsj:
# @
# @jillkerby:
# @ind…
# rt
# @fcp_ontario:
# rt
# @jaredbkeller:
# rt
# @bdgallof:
# rt
# @reutersus:
# rt
# @addthis
# @nbcnewsus
# @premiumwinners
# @thecurrentcbc:
# @
# @samanthanutt
# @au…
# rt
# @iclrcanada:
# @huffpostgreen
# rt
# @dost_pagasa:
# rt
# @nikki_bel
# @cory_lopes:
# rt
# @jarrettbay
# @hollaatbeanz:
# rt
# @tannerhuddle22
# @veronica_lopeez
# @bayerhealthcare
# @eloisa_amezcua:
# rt
# @johnfromcranber
# @meghanlibby
# @clapway:
# @inamre:
# rt
# @gomezlafraise
# @po_st
# @willsmith_14
# @dw_english:
# rt
# @laupetes
# (@dee's)
# @jurisfernandez
# @trossachssar:
# @scotfire_west
# @scotambservice
# @policescotland
# rt
# @worldvisionph:
# rt
# @itsgiovannap
# @ufhealth:
# rt
# @bignosestu
# @hilevans83
# @bts_twt
# @slimtaurus78
# @huffingtonpost:
# rt
# @abbey_marciano:
# @melissajoanhart
# @mamastasia
# rt
# @lisemerle:
# rt
# @solid_abscbn:
# rt
# @usatoday:
# rt
# @ancalerts
# rt
# @9newsaus:
# @damonews
# rt
# @graysondolan
# @icetyyc:
# rt
# @hypersentinel2
# @politicalcow
# @dopeytweeter
# @cokeboy1021
# @heyimchelsea_
# @poohaus
# @channelnewsasia:
# rt
# @angeliaranetuhh:
# rt
# @standardnews:
# rt
# @teacupiouist
# @harry_styles
# @foursquare!
# @jyangstar
# @garyeok
# @travelpulse
# “@realmindblowing:
# @paugasol:
# rt
# @skynews
# @reuters
# @ndtv
# \@kameronedwards:
# @nepalpolicehq:
# rt
# @8goingon80
# @hellonwheelsamc
# @how_fans
# @talkinghell
# @aguywithnolife:
# rt
# @cdcgov:
# rt
# @colemanwillis:
# rt
# @cppgeophysics:
# rt
# @jaygloves5
# @myrtlegroggins
# @macdonke:
# rt
# @brendhd
# @mettaworldpeace
# @icrc
# äóì@ajelive:breaking:magnitude
# @greggutfeld
# @dublinairport
# @motasnutellas
# @bandy6014
# @dressedstripped:
# @cleanclothes
# @ilrf
# rt
# rt@kelldawg21:
# @p0tus:
# rt
# @sammymoe
# @chimaincalgary:
# rt
# @reuters
# @walshy_93
# @baseballquotes1
# “@allygrace:
# @bromleyfalco:
# @krqemark
# rt
# @piscesareus:
# rt
# @sbluvsnickbsb
# @thematthewkeys:
# rt
# @coleymick
# @alyssamacadato:
# rt
# @rottenappletv:
# rt
# @cityofcalgary:
# rt
# @globalfloodnews:
# rt
# (@
# @worldwideelfs:
# rt
# @ddnewslive
# @nitishkumar
# @arvindkejriwal
# @@narendramodi
# @tareans
# @ndtv
# @ndtv_24x7
# @ndtv
# @guardianworld:
# rt
# @kellycryderman:
# rt
# @mas
# @narendramodi
# @dpradhanbjp
# @okcpd:
# @presbyterian
# @epcsheriff:
# @coemergency
# rt
# @pzfeed:
# rt
# @weebdacat:
# @scotent:
# rt
# @causewereguys:
# rt
# @gooddayatlanta
# @bedgood5:
# rt
# @dominiloka
# @spompls
# @kateagvaluer
# @pjdinho
# (@
# @mummy__issues
# @myrantypants
# @neesayer
# @findyoursimple
# @kirri_white
# @ohiou:
# rt
# @abc13houston:
# rt
# @cmnhospitals:
# rt
# @anointednika
# @cale_decoteau
# @independent
# @vivnsect:
# @nytimes
# rt
# @ktaeatafa
# @ficci_india:
# @s‰û_
# rt
# @clinehan21:
# @adamlevine
# @jocykimberly
# @big_picture
# @ollyofficial:
# @katiecouric:
# @time
# rt
# (@
# @bkonash)
# @zawminalex1
# @heinzaw46458789
# @lildavid29:
# rt
# @brunomars
# @anonirc:
# rt
# @mcaelashyanne
# @tutazgamd:
# rt
# @serendipitytc
# @ustupidbitch
# @inglewoodyyc:
# @philipturnbull:
# @inglewoodyyc
# @pagehanify:
# rt
# rt
# @theroyaltiex
# @matheussimass
# @cynestesia
# @usweekly
# @solartvnews:
# rt
# @undplive:
# rt
# @kcranews
# @redcross
# @martinhume:
# @hsaive
# rt
# @deec748
# @edmontonoilers
# @hallsy04
# @youtube
# @adambandt
# “@rosiemkane:
# @scrivenerD:
# rt
# @h_brinkmann:
# rt
# @dariusthompson8:
# rt
# @justinedata:
# rt
# @ashbby2012
# @conedison:
# rt
# @herologist
# @alexandrawilley
# @
# @bigmike_young15
# @kel_c_dawn
# (@
# @wasabi_lima
# @grazzia09)
# @rt_com:
# rt
# @deannacalder
# @literarygrrrl
# @glennrogers42
# @lympha13
# @billmckibben:
# rt
# @wakeupkoglin
# @laport006
# @kxyls:
# @andycthacker
# @anacristam
# @epigrammist:
# rt
# @zarrykisses_
# @narrynicotine
# @daniel_bonds:
# rt
# @graesonchance
# @todayshow:
# rt
# @pantalonesfuego
# @that1972bloke:
# rt
# @coachkwisdom:
# rt
# @libertyfrontpr:
# rt
# @shakespeare_co
# @accountingweb:
# rt
# @conenmorgan
# @karateturtles
# @aslanatay
# @theobserverny:
# rt
# @fark:
# rt
# @rapplerdotcom:
# @sandra_sully:
# @cha…
# rt
# @niamcentral
# @mynameisbatdog
# @lilduval:
# rt
# @
# @waseembadami
# @kadscapiz:
# rt
# @tacobell
# @revlucymeg
# @nbcnightlynews:
# rt
# @sgag_sg:
# @johnnyruffo
# @dzmmteleradyo
# @donrcampbell:
# rt
# @village
# @
# @pawel__brozek
# @tall_lanky_kid:
# rt
# @wally2603
# @lizvaughan09
# @luke_winkie
# @tay_bay_bee
# (@
# @clapclap_bravo:
# rt
# @telstra
# @rogersbuzz:
# rt
# @hausofduzzi
# @gawker:
# @eddielack
# @qasimali2389:
# rt
# @mccainenl
# @evelynlozada:
# rt
# @unmigration
# @flyopinemonkey
# @alyssawalter:
# @jamiefrazz
# rt
# @melissalisseth7
# @marissanbcla:
# rt
# @jondonnisonbbc:
# rt
# @ruckaruckaali
# @fbipressoffice:
# rt
# @reuters
# @mattsmith_2
# @mitchnichols17
# @jadesta36
# @cbsnews:
# rt
# @elsiefukofuka:
# rt
# @twc_hurricane:
# rt
# @prabalgurung
# @jasonmparsons
# @fejjeffery:
# rt
# @hyattconcierge
# @sexiiness_
# @wsj:
# rt
# @mitchyx10:
# rt
# @treysongz:
# rt
# @biebersrobot:
# rt
# @rlgroene:
# @nbcnews
# rt
# @
# @tr0bs:
# @noelsheppard:
# rt
# @shannonpoe:
# @kwtx
# rt
# rt
# @bpincott
# @bubblecarwash
# @2makeyewsmile:
# rt
# @shitnenshihasto:
# rt
# @justin_balaban
# @cbsdenver:
# @cbs4shaun:
# rt
# rt
# @kesspls
# @jvreims
# @mattgood:
# rt
# @djrotaryrachel:
# rt
# @uberfacts:
# rt
# @stcom:
# rt
# @ticklemeshawn
# @evebrigid
# @droz:
# rt
# @rickycarandang:
# rt
# @kenneyjason:
# rt
# @
# @batmannewscom
# @mobisher:
# @newsweekpak:
# rt
# @
# @vikeologist
# @itvnews:
# rt
# @souwanabasinger
# @jay_splashin:
# @lilhartbeat96
# @waterlooroad
# @sar_giuliani
# @theonlylincoln7
# @lucyero:
# rt
# @sim0n_seville:
# @abbeyshawn:
# rt
# rt
# (@
# @iamrockwell
# @buzzfeednews:
# (@micahgrimes)
# @joe_17
# @vandamcnn,
# @cnni,
# rt
# @sprint
# @
# @blogsofwar:
# @sneakei
# @felicityward:
# rt
# @dstaples
# @hehecore
# @panewzer:
# rt
# @a_riley10
# (@
# @blakeshelton
# @tomsatercnn:
# @brandoncnn
# @cnni
# rt
# #2150f\rt@cnnbrk:
# @
# @cbcalerts:
# rt
# @persecutionnews:
# rt
# @fusiliyyc
# @rumblevideo
# @miamiherald:
# rt
# @mailonline
# @aubilenon
# @markkriegsman
# @abhijitmajumder
# @jkfloodrelief,
# @dost_pagasa
# @debraward:
# rt
# @dna:
# rt
# (@
# @nationalpost:
# rt
# @fabiankeiser:
# rt
# @garymanser
# @team1040
# @neda_semnani:
# @dansinker)
# rt
# @edmravergirl
# @er0tikka
# @ilianilamorena
# @real_liam_payne
# @yv5venet:
# rt
# @jujusocrazy:
# @matthew_tingle
# “@cnnbrk:
# @svegaf:
# @carrillopablo
# rt
# @joshuaadamsrock
# @trap_sheep:
# rt
# @pfew_hq:
# rt
# @thames21
# @mcsuk
# @kayleeroberts10:
# @ottteri:
# @incindia
# @jhasaâ€¦
# rt
# @kwonjifan:
# @kg1313
# @kwonjifan
# @amstyl
# @delapour
# @ellepiari
# @ms_lipps
# @poeäó_
# rt
# @edwinsevidal
# @perezhilton:
# rt
# @alisalmanalvi:
# rt
# @joefryer:
# rt
# @ghfps
# @kloveradio:
# rt
# @corbellatoris
# rt
# @michael_sch
# @mackayim:
# rt
# @brianmoran
# @aliaa08
# @rwsurfergirl:
# rt
# @namgoreng
# @paradiseharryxx:
# @yychelps
# @breakingweather:
# rt
# @saraah_5sos
# @allisoncroghan:
# rt
# @iomasiapacific:
# @iom_news
# rt
# @rvrb:
# rt
# @brookeclan14
# @davisjessd2014
# @valerie_0225
# @amyrosekathryn:
# rt
# @davisjessd2014
# @mrlippman
# @thisisrobthomas
# rt
# @alex_sowell12
# @suzunkitty:
# rt
# @worldvisionph
# @childishdarino
# @takingphotos:
# rt
# @we12travel:
# rt
# @snsdaddicted:
# rt
# @bbcbreaking:
# rt
# @
# @wfaachannel8
# @10pm
# @gretawire:
# @foâ€¦
# rt
# @_k_a_young:
# rt
# @indro_shs:
# @612brisbane
# @7newsbrisbane
# @9newsbrisbane
# rt
# rt
# @healthranger
# @m_mccoy
# @colestreeper1
# @lindatini
# @arufflife
# @foursquare!
# @tariq_vaid:
# @nâ€¦
# rt
# @amykayes
# @maiamajumder:
# rt
# @imalwayscookin
# @australian:
# rt
# @skynewsaust:
# @ninabstevens:
# rt
# @8evenpro:
# rt
# @yahooscreen
# @gurkha_brigade
# @pahartrustnepal
# @qge_g200
# @l0v3xc3ss:
# rt
# \@bernadette_abs:
# @dost_pagasa\""
# @thedjiceberg:
# rt
# @shanevictorino:
# rt
# @sebtsb
# @narendramodi
# @bowmaotruthteam:
# @epn
# @presidenciamx
# rt
# -@entershikari
# @j_lee30
# @hurricane
# @rakeshsinha01:
# rt
# @odyssey_guide:
# rt
# rt
# @wsjworld
# @wsj:
# rt
# ���@lordbrathwaite:
# @bethangsioco:
# rt
# @tharaka_
# @ap
# @agbizwire:
# rt
# @2009superglide:
# rt
# @amznfavorites
# rt
# @montauktackle:
# rt
# @iharryworldwide:
# rt
# @phuonglazie
# @lizhphoto
# @maddiedachs
# @sammi_landsman
# @briannabaenke
# @parksykcco:
# @caseycoutts
# @kccocalgary
# \@philippinestar:
# @pwu_manila\""
# @madina_e_sani:
# rt
# @chawash_baloch:
# rt
# @saurjk
# @spokespersonmod
# @lakers
# @yucancallmejim:
# rt
# @loucathsports:
# rt
# @cheetahpizzas:
# @maddow
# rt
# @prodr1977
# @cep_observer
# @mariavinci7:
# rt
# @ieentertainment
# @rajkumarhirani
# @aamir_khan
# @kmp091:
# rt
# @t_swaggga:
# rt
# @ap:
# rt
# @mackayim:
# rt
# @calum5sos
# @namikkeren
# @crazycaptainn
# @varun_dvn
# @aliaa08
# @usacehq
# @wjxt4
# @twhiddleston
# @drtwofive
# @tomdumontnd:
# rt
# @daniellefayyy:
# rt
# @melissamay1:
# rt
# @sinucabello:
# rt
# @kyliepc
# @kingteejay
# @cnnbrk:
# rt
# @sippycupmom:
# @kezunz:
# rt
# @internews
# @shane_hoban:
# @bonitalee_:
# @ccbp
# @stuartcalimport
# @theqldpremier
# @washingtonpost
# @martinenserink:
# @kakape
# rt
# @mongogoescrazy
# @wfaachannel8
# @realdonaldtrump
# @newday:
# @barackobama
# rt
# @cpsa_ca:
# rt
# @kristenmking
# @kristin_cam
# @zachnews:
# @funny_truth:
# @delaware_dhss:
# rt
# @xoajamariee:
# @smitaprakash:
# rt
# @aligaator_:
# rt
# @lifewortheating:
# rt
# @kogan
# rt
# rt
# @kencampbell66:
# @ap
# rt
# @microbeworld:
# rt
# @kprc2:
# rt
# @nytnow
# @shaheenx:
# rt
# @bryce_hamilton
# @foursquare!
# @brooke_xo_:
# @ap:
# rt
# @leohickman:
# rt
# @htlbhouston
# @jud_cyberteam:
# @fifpakistan
# rt
# @militarydotcom
# @keithurban
# @keithharkin
# \n\n@docshayji
# @abdulkhaleq_uae
# @saadbin6iflah
# @divyaconnects:
# @bbchindi
# rt
# @secondavesagas
# @mrpeterandre
# @vagabondbeers)
# @youngnina__:
# rt
# @brewsonbroad:
# @sammyhagar
# rt
# @buzzfeed:
# rt
# @kool1015calgary:
# @tarzandan
# @nikireitmayer
# @wilde_one
# rt
# @emmaayersx:
# @itsssjerome
# rt
# @adam_wilkinson:
# rt
# @_alexandrax3_:
# rt
# @theage
# @timeworld
# @cstshaw:
# rt
# @swishdreams101:
# @cabopro:
# rt
# “@calgaryparking:
# @cityofcalgary
# @vintagevision80:
# rt
# @itsydg:
# @stassievee
# rt
# @jaltucher:
# rt
# @govinslee:
# rt
# @kristinclaire29
# @hunterhayes:
# rt
# @9newsgoldcoast
# @chdmz:
# @ashmash274
# @jeremymckinnon
# @sara_r3sistance
# @ampcalgary:
# rt
# @breakingnewpak:
# rt
# @youtube
# @skippy6gaming
# @ryanruggiero:
# rt
# @jeffndyer:
# rt
# @markusoff:
# rt
# @
# @bdutt:
# @pmoindia
# rt
# @arshkaur23:
# rt
# @worldvisionaus
# @calum36chambers
# @a_darlingmp:
# rt
# @youtube
# @smh:
# rt
# @sirbeezalot
# @bullbag2006:
# rt
# @zhoumi_419:
# rt
# @simplysmarttrav
# @brianefallon
# @clintonfdn
# @thewatchers_:
# rt
# @kfor:
# rt
# @exoworldina:
# rt
# @cnnbrk:
# rt
# @rudawenglish:
# @osamagolpy
# rt
# @tayla_ree:
# @timhortonsnews)
# @gurlstrange
# @sharethis
# @phill_butters
# @capital967
# @magalyperu
# @malditaternura
# @tiffanythelma_x:
# rt
# @scott7stevenson:
# rt
# @obfusc8:
# rt
# @seirenhee:
# rt
# @cammacintoshcbc:
# rt
# @skylareyann:
# @ibeatupkrabbz:
# rt
# @joeyytee
# @thekevinryder:
# rt
# @r2pindex
# @metronorth
# @jmonecn
# @dantencer
# @globeandmail:
# rt
# @prabhasp
# @chrisreuters:
# rt
# @aarondevoe
# @paleface31
# @pac43~&gt;
# @usgsted:
# rt
# @ryanmaue:
# rt
# @
# @weatherchannel:
# rt
# @mvadera:
# rt
# @cut4:
# @yankees
# rt
# @producersiovhan:
# @kgwnews
# rt
# @polyvinyl:
# @sslyby's
# rt
# @gregorydjohnsen
# @mai_rodrigz:
# @robertspeta
# @sol
# rt
# @dailymail:
# rt
# @gofundme
# @gentlemanfight
# @coreywilson:
# @nenshi
# rt
# @jimwagy:
# @jdechristopher
# @avhigail
# @urbanmythicajp
# @thisismaddness
# @deped_ph:
# rt
# @gohamnewt
# ____@dave_mallet:
# @mta
# (@life
# @beraardesco
# @blairberardesco
# @jay___rose:
# rt
# strategist\n@ammar82
# @russianmachine:
# @greenlife52
# rt
# @martinez_ice:
# rt
# @cmdr_hadfield
# @javedazizkhan:
# @aamiryatoo
# rt
# @drraisyatim
# @7eleven
# @imkindaabigdill
# @melissadoyle
# @melissadoyle
# @sunriseon7
# @savechildrenuk:
# rt
# @eyprelrows:
# rt
# @dance4lifenl
# @dance4lifeint
# (@
# @boffers)
# “@ancalerts:
# @timhortons
# @qpsmedia:
# rt
# @deepgreendesign:
# @armstronggn
# rt
# @wckdstepmomster:
# rt
# @gretchenl0703:
# rt
# @lepak_:
# rt
# @byhenrywu
# @cuna
# rt
# @tumisangmadiba
# @casslilronda
# @efcgraeme
# @franamma
# @efcafrica
# @mattbuirski
# @dominatordoyle
# @thecapital15:
# rt
# @irinnews:
# rt
# @youranonlive:
# rt
# @irisyaadam:
# rt
# @leannrobin
# @dee_d_cee2
# @kimbas238
# @georgiaclarkk_:
# @jenn822:
# rt
# @industriall_gu
# rt
# @kissmewillsinge
# rt
# @dictionarycom
# @natalia_cooper9:
# @thetodayshow
# rt
# @
# @kyleravens20
# @realdonaldtrump
# @juanxi:
# rt
# @juliettelecoq1
# @sav01:
# rt
# @
# @lyndseydiane22:
# rt
# @dakotastraub:
# rt
# @15moferadio
# @heavybag201
# @battle_dom
# @qotring
# @battlerapchris
# @hughes1128
# @yowan
# @ap
# @ntanewsnow:
# rt
# @snapchatlife:
# #snapchatproblems@jennakonschuk
# @ntvuganda
# i@dailymonitor#news
# @edmontonesks
# @ilseselena1
# @kvue:
# rt
# @axafortourists:
# @trudynixon
# rt
# @swstheband
# @piercetheveil
# gbam!!!@gidi_gossip:
# @dbrickashaw
# @ibnlive:
# rt
# @harolditz:
# rt
# @yogrishiramdev
# @broganmcmanus
# @carolyn_burke
# @citybarbeque
# @redcrosscanada:
# rt
# @skynews:
# rt
# “@travkus:
# @abbeyoldham
# @4catsinglewood
# rt
# @metroannalise:
# rt
# @cgyfarmersmarkt:
# @calgaryfoodbank
# rt
# @missis_mckenzie:
# rt
# @narendramodi
# @presssec:
# rt
# @jasontobeone:
# rt
# @boembrbettytyee:
# @ca_boe_news
# rt
# @midokumo
# @grybauskaite_lt:
# rt
# @baylors3
# @rangers
# @iamsrk:
# rt
# @mackayim
# @saudimoh
# @chefcamd,
# @corkonthenfl:
# rt
# @msn:
# rt
# @kaceymusgraves:
# rt
# @dougkscott
# \@philklotzbach:
# @luukvos:
# rt
# @ifullington
# @hillaryscottla
# @nbcthevoice
# !@youngreek732
# @lickmah_beauty
# @radiopakistan:
# rt
# @liberalcrone
# @c95:
# rt
# @nbcnews
# @shoyukotakirin
# @babyboi2001:
# rt
# @_tylerchurchill
# @
# @safetygirl100:
# @48hours
# rt
# @prettyisugly
# @ap:
# @breakingweather:
# lmaooo@thisismykl:
# @alexandersugar
# @cazorlaplay
# @princesscathh
# @kwissaaaaan:
# rt
# @anthropologie
# @
# @marleematlin:
# @senator_baloch:
# rt
# @globaltvnews:
# rt
# @justicedotorg:
# rt
# @pjschnepp:
# rt
# @5sos
# @willakaurhost:
# rt
# @smartcares:
# rt
# @wpxi
# @livescience:
# rt
# @nasascan:
# rt
# @cbccalgary
# @mfadden8:
# rt
# @theotypes:
# rt
# @m4ttanderson
# @salarmyeds'
# @dfmzz
# @fantasticon86
# @alyssa_eby
# @cherakimiko:
# rt
# @lupevete:
# @tyllahph
# @jackienatalydlt
# @cnn
# @lifeasbros:
# @censorednewsnow
# rt
# @m_dubya_33
# @mjdwarner:
# rt
# @mychonny
# @ancalerts:
# rt
# @gladecentre:
# rt
# @jroc718
# @mike1_w
# @mattkozarabc7:
# @abcny7
# rt
# @dickiev:
# rt
# @msovak
# @jesse_johnston
# @wpbf25news:
# rt
# @niallofficial
# @asiancurryaward
# @vimal2100
# @neha_aks
# @comubh
# @ladyofchrist15:
# rt
# @abpremiercomms:
# @townofhighriv…	en	1	informative
# 778251153	disaster_events	dsm-cf	#hot
# #best	en	1	informative
# DD5813643914854400	DDDD_queensland_floods-ontopic	crisislext6	@wwos9
# @napacoredcross:
# @pge4me
# #â€¦	en	na	informative
# 204691789	2011_joplin_tornado-a131709	iscram13	@mytrainerbob
# @wsj:
# @2dayfmsydney:
# http:t.codzkndklrs9	en	na	informative
# 339447073042751488	DDDD_oklahoma_tornado-ontopic	crisislext6	@retrofanatic23
# @lawstreetmedia
# @amahoney8672
# @johnspatricc:
# rt
# @dost_pagasa
# @femfreq
# @extremestorms:
# rt
# @vijayprashad:
# rt
# @frackfree:
# rt
# @sydneyyykeith:
# @soffiaxalexeis
# @shivonleigh
# rt
# @tamaldas8:
# â€œ@arvindkejriwal:
# rt
# @srqpolicefdtn
# @921ctq
# @master777ssss:
# rt
# @livemint:
# rt
# @
# @todayonline:
# rt
# @katedoak:
# rt
# @bjpsudhanrss:
# rt
# @youranonnews:
# rt
# @6abc:
# @laingcasey
# @ap:
# rt
# @joaquinkuchar:
# rt
# @gmanews:lea
# wow!@msleasalonga
# @dinnerwithjulie:
# rt
# @timesofindia
# @emirates
# @heatherhahnn:
# rt
# @willhounsome1D3
# @cafeteto
# @abc7:
# rt
# @angelafritz
# @queenpetrak:
# rt
# @huffingtonpost:
# rt
# @deeptisachdeva_
# @jamiekilstein:
# rt
# @bostonglobe:
# rt
# @theejessicadee
# @sjh2222:
# rt
# @nydailynews:
# rt
# @jianghomeshi:
# rt
# @paulobrien1016:
# rt
# rt
# @m_ro_co
# @nygovcuomo:
# @diptyqueparis
# @chateau
# @
# @danielde93
# @my3acres
# @sonningcutting:
# rt
# @kishorenepal
# @nppoet
# @soy_bonitax3
# nowὣ1@tmobile
# @ctvedmonton:
# @ctvnews
# rt
# @cdcgov:
# rt
# @israelmfa:
# rt
# @robertacbs5:
# @birdrangers01:
# @abcnorthcoast
# rt
# @shoortstuff_xo:
# @garreton:
# rt
# @abscbnnews:
# rt
# @
# @meaindia
# @meacontrolroom
# @narendramodi
# @narendramodi_in
# @benbima
# @denverpost:
# @aldosvaldi
# rt
# @marcus_m23:
# @brittanie_renae
# @caarlax
# @fox4:
# rt
# @itz2freshhjames:
# rt
# @jtorresbjj
# @essentialbjj
# @shahad_alarenan
# @roomeetimes:
# rt
# @simply_unique11:
# rt
# @cp24:
# rt
# @juan_collio:
# rt
# @amitabhbachan:
# rt
# @pinayquotes_:
# @siham_a_
# @whydontwemusic
# @elreynetwork
# @
# @starbucks:
# @starbuckscanada:
# rt
# rt
# @ynb2210
# “@lionsxll_fan:
# @ingnycmarathon:
# @dimemag:
# rt
# @caperspurge22
# @team_dr3
# @tonynewscamera
# @timepictures
# (@
# äóì@txtrendychick:
# @utsandiego:
# rt
# @ecointernet
# rt
# @660news:
# rt
# @ancalerts:
# rt
# @
# @chrissycostanza
# @rvento_:
# @gideonresnick:
# rt
# @michellemccann
# @david_williamso
# @sheilawalsh:
# rt
# @adambandt
# @mtcarmelelem:
# rt
# @kyunglahcnn:
# rt
# @stevenportnoy:
# rt
# @mrslac2017
# @lisa_examiner:
# rt
# @rihannanumbtwo:
# @imkerwinking:
# @jacobwhitesides
# @amunhay
# @hammodi911
# @lady_afrah
# @muraisireddevil
# @bandinellosaul
# @ascatrysse
# @nay_realass:
# @tedhouk
# @ancalerts:
# @dzmmteleradyo
# rt
# @central
# @cnnbrk:
# rt
# @tweet_bender:
# rt
# @rosahwangctv:
# @ctvbeauchemin
# @sawhiteplains:
# @vdubnyc
# rt
# @taptu
# @
# @cshayler1
# @bbcnewsasia:
# rt
# @alyssaridgeway9:
# @sage_alexa_
# @desstmariee
# @gerdozone
# @nbcnewspictures
# @movetheworld
# @joansmalls:
# rt
# @ap:
# rt
# @propublica
# @sara_yale
# @styleeyes:
# rt
# @itsfunnylife:
# @ask_spectrum
# @getspectrum
# @brighthouse
# @wiltshiretimes:
# rt
# @margaretherapy:
# @ckaaer
# rt
# @townofhighriver:
# rt
# @nissanguru
# @withapoetsstyle
# @bri_dendler
# @northemmosphere:
# rt
# @narendramodi
# @campbellscorral:
# rt
# @nbcthevoice:
# @starbucks!
# @unitedway
# rt
# @smkdunn:
# rt
# ���@ilikewgw:
# @brendonbossy
# @b105brisbane
# @annajhenderson:
# @juliebishopmp
# rt
# @tourismjournal:
# rt
# @torikelly
# @connectcatholic:
# â€œ@mailonline:
# rt
# @abcemergency:
# rt
# @daveyperry:
# rt
# @marieplusgrace:
# rt
# @abc7robert:
# @
# rt
# @davepetley
# @parfaittweets
# @ashwagw
# @nenshi:
# @hwesleye:
# @radioyyc
# rt
# @mayra_maldonado:
# @simonepress
# @aggancarski
# @thesufisoul:
# rt
# @enockananda:
# rt
# @midnight4trump6
# @taylorswift13
# @lishas67
# @alkoleyable
# @hannahmorgan043
# @yep_xx
# @oksana_first
# @rt_com:
# rt
# @liveleakさんから
# @mfbrooklyn
# @indiatvnews)
# @channelnewsasia:
# rt
# @vergotaswey:
# @kixify
# rt
# @abbsbro
# @
# @woolseydrew:
# rt
# @robpulsenews
# @huyovoetripolye
# @jnsmall
# rt
# @endo_42o:
# rt
# ���@cnn:
# @blueshue22:
# @ajgcorporate:
# rt
# rt
# @flowingdata
# @cokeboy1021
# @mayorsalliance:
# @cdcgov
# rt
# @shell_canada:
# rt
# @huffpostgreen
# @lschu92
# @jeremylabadie
# @calgarytransit
# @philippinestar:
# rt
# @msfulwylie
# @weatherchannel
# @freedomforthwin:
# rt
# @typhoonfury:
# rt
# @mariodacat
# @breakingnews:
# @cbcalerts
# rt
# @murtazageonews:
# rt
# @cspdpio
# @ryanprast
# @peanutchews
# @ahalim200:
# rt
# @segunxx:
# @jenniessweetz:
# rt
# @theglamgoddess
# @themaine
# @atmosphere:
# rt
# (@ifalasteen):\n\nand
# @bynickdean:
# @gdickson
# @patrickmwalker1
# @startelegram
# @antderosa:
# rt
# @ironorehopper:
# @flutrackers
# rt
# @@ajenglish
# @wsj:
# rt
# (@
# @httweets:
# rt
# @unvolunteers:
# rt
# @knakasmarshie
# @jaymohr37
# @danbeyeronfox
# @afn_updates:
# @shawnatleo
# rt
# @aldjohnmar:
# rt
# @weatherofindia
# @kherr122
# @politicsisdirty
# @chinmayi
# @khushsundar
# @i_actorsasi
# @bigeasymike1981:
# @vp:
# @whitehouse:
# rt
# @austinmahone
# @xtina:
# @wfp
# rt
# @thenewshype
# @5hark_lee
# @davidcurnowabc:
# @mattwordsworth's
# @abc730
# rt
# @breeolson
# @ryanagar7
# @realtonyrocha:
# @carlachamorros
# rt
# @ofcfootball:
# rt
# @aportzline:
# @kschroeder1720
# rt
# @gmanews:
# @jun_veneracion
# rt
# @craigowens
# @cnn:
# rt
# @medinastormcast:
# @weatherchannel
# rt
# @pnj…
# @bpincott:
# rt
# @burgolive
# @edfringe?
# @m00nf00l
# @summerhallery
# @cnnnedesk:
# rt
# @gregabbott_tx:
# @madelncanada:
# rt
# @willbrinson:
# @cbsnews
# rt
# @scheuerjo:
# @undp
# rt
# @jamienye
# @joshmalina
# @denialjkap
# @nameless
# @parasitecod
# @sammich___:
# @jakev_bu13
# @cory_kennedy
# @
# @houstonchron
# @caitikeene
# @itsmeekmill:
# @worldjonasnews:
# rt
# @repasencio
# @nbc6
# @harto
# @joshthesmoke:
# rt
# @ozzieguillen:
# rt
# @markusoff:
# @carrietait
# rt
# rt
# â€œ@headlinenews:
# @lmbr_50
# @johnmqc:
# @40commando
# rt
# @samaatv:
# @sharethis
# rt
# @umarufofana:
# rt
# @12alec:
# @caster_24
# @greenhousenyt:
# rt
# @nprnews:
# rt
# @mzmary_88
# @everydaypaleo
# @kevvylam:
# rt
# @joenbc
# @bfeather450:
# rt
# @jimparedes:
# @joeshowradio:
# @joerogan
# rt
# @fortisalberta
# @adamrichman
# @odyssey_guide:
# rt
# @aline_carr:
# @unocha_rop
# rt
# @heidewrite:
# @_4urimagination
# @54kdoctors
# @globalcalgary
# @wsvn
# @dawn_com:
# rt
# @team_kapamilya:
# @dost_pagasa's
# @bloombergnews
# @ashlynxxnicolee
# @thecanadacom
# @cnnashleigh:
# @cnn
# @11pm
# @cbs47@ksee24
# @42megasxlr:
# rt
# @boybalita911:
# rt
# @refugeeblues:
# @pmoindia
# rt
# @slone:
# rt
# @abc:
# rt
# @james_yammouni
# @jmathews7
# @nickkeyko
# @mvmtwatches
# @cityofcalgary:
# rt
# @nis111284
# @r5_fire_news:
# rt
# @rothna_begum
# @hrw
# @libertytf:
# rt
# @
# @
# @
# @youtube
# @onelastpoem:
# @140elect:
# rt
# “@philstarnews:
# @smh:
# rt
# @cebuinfocen:
# rt
# @yourridicious
# @atheist_club
# @panahontv
# @ptvph
# @scottgian
# @broelisoriano
# @miilkkk:
# rt
# @sommlike_dat
# @indianacsmedia
# @unicef
# @diegirl:
# rt
# @starbucks
# @nykaed_
# @coolwhale_mufc:
# bombing?@emveepee_1:
# rt
# @howtogetawayabc
# @savechildrenph
# @reuters:
# rt
# rt
# @ducidni
# @trishvelarmino:
# rt
# @shariahbailey03:
# @hollymawilliams
# @operationsafe
# @andersoncooper
# @el_raddo
# @grumpycat
# @hyattconcierge
# @theage
# @sohaib_nehal:
# @shahidmasooddr
# rt
# @therunnergirls1:
# rt
# @breakingnews:
# @reuters
# rt
# @cityofcalgary:
# rt
# @federalalliance
# @tinnaafaceee:
# rt
# @cbcnb:
# rt
# @austinramzy:
# rt
# @bcameron7:
# rt
# @youtube
# @demarko_gage:
# rt
# @scoopit
# @dipakbhattarai:
# rt
# @verge
# @cnnbrk
# @chelci_marie:
# @frantownsend:
# rt
# @pmharper
# @mamtainsan02:
# rt
# @hklatt26
# @d_pagexxi:
# rt
# @epsonamerica,
# @meaindia:
# rt
# @steph_avon
# @mswami:
# rt
# @easy_branches
# @thehill
# @sfgate
# @raniakhalek:
# rt
# @rescueph
# @rescue5ph
# @moveph
# @giasison
# @theonion:
# rt
# @barackobama
# @
# @marinagiacomin:
# @globeandmail
# @redgypsee
# rt
# @d8marko:
# rt
# @esri
# @simpsonspired:
# @
# rt
# @theumno:
# @kellynehls:
# rt
# @barackobama
# @bradwjackson
# (@
# @sskroughriders
# @
# @manateeccps
# @franktbh
# @salsapockbill24
# @theloganalyssa
# @miss_sarahnz
# @lucasnadeau1:
# rt
# @benfergusonshow:
# rt
# @sharethis
# rt
# @gmanews:
# @micaelapapa
# rt
# (@
# @usgsted:
# rt
# @wltx:
# @ap:
# rt
# rt
# @cityofcalgary
# @gaylewestover
# @abscbnchannel2:
# rt
# @elvenage
# @panahontv
# @thecurrentcbc:
# rt
# @samanthameii
# @deped_ph:
# rt
# @colleenferreira:
# @westin
# rt
# @dknhs46:
# rt
# @gaycarboys
# @lateline
# @barryofarrell:
# rt
# @emilyrsutton:
# rt
# @alexhern
# @syria
# @graciepick
# @naparbier
# @
# @theesbm:
# @lil_woadie
# @heartdino:
# rt
# @dance_xross
# @nbcnews:
# rt
# @colerightley:
# rt
# @griffmla:
# rt
# @mariashriver
# @keightyem:
# rt
# @bigmeech1005:
# @alertlastminute:
# rt
# @oxfamamerica:
# @winnie_byanyima
# rt
# @merchantscafe
# @windlady:
# rt
# @jeremiahbrent:
# rt
# @its_exo
# @kasmcrae:
# rt
# @totaltrafficden:
# rt
# @oswaldo_gloria
# @youtube
# @cypress_k8
# @mdcpssouth
# @gojam_i_am
# @uranusaturn
# rt
# @cnn
# @kocobrad:
# rt
# @afp
# @guardianeco:
# rt
# @asgharchohan86
# @adilghumro
# @unison_humbpol:
# rt
# @nickiminaj
# @fillwerrell:
# @canadacomhealth:
# @helenbranswell
# rt
# @migzzubiri:
# rt
# @tattooedzarry:
# rt
# @b_luss:
# rt
# @7news:
# rt
# @imkindaabigdill
# @
# @nitinr_
# @sandy0013
# @govph:
# rt
# @samanthawftv:
# @wftv
# rt
# @fema
# @meimeifoodtruck
# @edgespeeder06:
# rt
# @globalnews:
# rt
# @lizbon
# @kidicalmassdc
# @joshgroban
# @marty2634:
# rt
# @rachoates
# @carterhulsey
# @thedenison
# @christoferdrew
# @davidmora
# “@edmontonjournal:
# @tangurlz:
# rt
# @sterling_holmes
# @thiskidmook
# @junsuisengen
# @treporter5:
# @flcities:
# @flgovscott
# rt
# @fatimaali52:
# rt
# @wbcsays
# @forestservice
# @anthonyaydin?
# @savechildrenaus:
# rt
# @1dejiaantonia
# @darealest015
# @koya_danielle
# @janayrobinson2
# @gaslightboston
# @jessmcgonagle
# @macmark:
# rt
# @lindsey_2510:
# rt
# @ctvkarenowen:
# rt
# @who:
# rt
# @girlgiveme_that
# @hrmcanada
# @niggaslove_riah:
# @theconclub
# @nadiaalexis21
# @britneymorgan_5
# @indianajoe113:
# @nwsiwx
# rt
# @alexavilla13:
# rt
# @tayytta:
# rt
# @michellemalkin:
# @twitchyteam
# rt
# @queenhighlightt
# @kimkardashian
# @2dbabe
# @bbcnews
# @mrmikejay:
# rt
# @noaa:
# @noaasatellites
# rt
# @bballproblemz:
# @usgbc
# @grupocne
# @katelhunter
# @youranonnews
# @huffpostgay
# @unusuaiquestion
# @mkyshprobz
# @nytimesworld:
# @tangledjourneys
# rt
# @arcteryx
# @photojack
# @djsloejoe
# @
# @
# @darrendreger
# @iammvp
# @nenshi
# @manvelseafood:
# rt
# @alex_harnett:
# rt
# @fubiz
# @1sistr:
# rt
# @wsvn:
# @usairforce
# @sibpd
# rt
# @scribblelive
# @ac360:
# rt
# @dougie_1888:
# rt
# @longpre11:
# @redcrossab;
# rt
# @asdfghjessica_:
# rt
# @son_of_fratter:
# rt
# @joetowerscards:
# rt
# @redcrossab:
# rt
# @mattielbreaux
# @nasagoddard:
# rt
# @catholicmiami:
# rt
# @chinnybastianic
# @raveandrollhard
# @lastgreatstand:
# rt
# @threatconnect
# @news1130radio:
# rt
# @peterdoherty7:
# rt
# @tirayekream_:
# “@dailythunder:
# @roach_april
# @bwadwilliams
# @foodnavasia
# @demetrapitta
# @carmeloorlando:
# @realdonaldtrump?
# rt
# (@
# @idph:
# rt
# @topos
# @thekidrauhlking:
# rt
# @bexarcosheriff
# @adil_lateef:
# rt
# @leahhouston12:
# rt
# @yarnharlot
# @ndtv:
# rt
# @delaneyshowers
# @arvindkejriwal
# @drgpradhan
# @diyeiyromero_:
# @imsergeramos:
# rt
# @asandyhurricane:
# rt
# @klaus30wood
# @target
# @iamsrk:
# rt
# @preetikarules:
# rt
# @laughingsquid:
# rt
# @realseunkuti:
# rt
# @tfchurches:
# rt
# @bethcullendc:
# rt
# @bern_morley
# @sugarscape:
# @rzapp815
# @lifestr3am
# @tobeymonster
# @nicolerrabbit:
# @sandraklis:
# rt
# @
# @sancheezyrican
# @tobeymonster
# @billsimmons:
# rt
# @artwellguide:
# @jerrysaltz)
# rt
# @skynews:
# rt
# @orgasmicgomez
# @onedirslaytion
# @carriemtenney
# @exoffical_:
# rt
# @kalem22
# @emily_lopez:
# rt
# @robertstrachan
# @paulbrandt
# rt
# rt
# @brose019
# @scph_pio:
# @davidsuzukifdn:
# rt
# rt
# @seaoftime
# @blackirishi:
# @cdcgov
# rt
# @talonro
# @kyrston_dozier
# @saleenaasher
# @buzzfeed:
# rt
# @wflanger
# @ynkutner
# @kenroth
# @ostrov_a
# @kenroth
# @wsj:
# rt
# @boxhq
# @teamrubicon,
# @oxfamamerica,
# @samaritanspurse
# @nethope_org
# @gh0stie5
# @fema:
# rt
# @roncorning:
# @wfaachannel8
# rt
# @okwesternwheel:
# rt
# (@
# @weatherph:
# rt
# @rdfrs:
# rt
# @idangs_:
# rt
# @johnlegend:
# rt
# @newshour
# @tractor_barrow
# @example
# @ucobass1
# @alexbelloli
# @shadealveranga:
# @ms_sharinbaybeh:
# rt
# @_geenie_
# @headovmetal:
# rt
# @worldvisionph:
# rt
# @nadpres:
# rt
# @the_sexiiiest
# @jimintheair
# @hitthepost
# @greeblemonkey:
# @brandash's
# rt
# @custosdivini:
# rt
# @biospherelab:
# rt
# @themikeod
# @juliechen
# @nst_online:
# rt
# @icacoop‚ä¶
# @themoedee
# rt
# @ap:
# rt
# @everywhereeng
# @youralberta
# @wr_record
# @vallie:
# rt
# @muntons
# @torontostar
# @pzfeed:
# rt
# @mchammer
# @kool1015calgary
# @ddnewslive:
# rt
# @rod_rocket
# @tobyplowman:
# rt
# @defender_pk:
# rt
# @panahontv
# @ptvph
# @elenaintra:
# rt
# @minsooey
# @blakeshelton
# @katewilson0605
# @minimcdoc:
# rt
# @speedreads:
# rt
# @yani_bih:
# rt
# @dakotamc_
# @lilyanaromero:
# @archdiocglasgow:
# rt
# @guardian:
# rt
# @thecriszuniga
# rt
# @mean_pooh:
# @sunriseon7:
# rt
# rt
# @prbdata:
# rt
# @newsbreaker:
# @afp
# rt
# @theahrnndz
# @carbuyeruk
# @sonumb8:
# @bbsbhutan
# rt
# @nicci_isneechee:
# @thombri
# @davisneal9:
# rt
# @meaindia:
# rt
# @foxnews:
# rt
# @blackvoices:
# rt
# @weathernetwork:
# @margovisser
# rt
# rt
# @yycflood:
# “@sheldondyck:
# rt
# @youtube
# @melindabam:
# @psalms_proverbs:
# rt
# @hermosakorea1
# @danielhenney
# @philandchris
# @policescotland:
# rt
# @jonasbrothers:
# rt
# @abc7ny:
# rt
# @leedsinspired:
# @the_tetley
# @parksboardfacts
# @ap
# @smiffy60:
# @zach_smith7
# rt
# @robmarcianocnn:
# rt
# @_aleeexsm
# @_itspebblesbabi:
# rt
# @fema
# @
# @hpmnews887
# @houstonpubmedia
# @barceionistas:
# @milo5bernal]
# rt
# @livescoresph:
# rt
# @gatman7:
# rt
# @josephjett
# @westcoastwldcat
# @eliiicordova:
# rt
# @rifatjawaid
# @jantakareporter
# rt
# @reiabriggsconnor
# @sugarxspice
# @uberfacts:
# @marek1330
# @kirstiealley
# @therealjenarri_
# @hyped_gaming123:
# @gamerrt__
# rt
# @mepadil
# @edcoop5000
# @crowdboarders
# @manatrue
# @jordiemack17
# @sakatunayan:
# rt
# @travelxpert:
# rt
# @kentuckyguard
# @russia
# @kakaotalkph:
# @inquirerdotnet
# rt
# @raestuhr
# @rt_com:
# @janney_h
# rt
# @djschemes:
# rt
# @russdiabo:
# @ezralevant
# rt
# @lonepercy:
# rt
# @
# @hislifeofficial:
# rt
# @texasroadhouse
# @bayfitness:
# rt
# @alastairmci:
# rt
# @tim_blanks
# @blessed_moee:
# @inglewoodyyc
# rt
# @evalongoria:
# rt
# @robertdmcneill:
# rt
# @andiecbc
# @
# @
# @virginaustralia
# @martharrobinson
# @cluelesshelen:
# rt
# @alyssaallen13
# @rickygervais
# @deefinley
# @epcor:
# rt
# @kelseydduncan
# @austinpetsalive:
# rt
# @paul_cashbolt:
# rt
# @hakushondaimao
# @
# @
# @allis0ntalbot
# @newcastleherald:
# rt
# @jesybasco:
# @diversionary:
# rt
# @abcworldnews:
# rt
# @wilmbluerocks:
# rt
# @mashable:
# rt
# @cgyfirefighters
# @cityofcalgary
# @canadahelps
# @matadornetwork:
# rt
# @drunk_bitchez
# @fractivist:
# @anarchoanon
# rt
# @youtube
# @
# @forever_like21
# rt“@gmanews:
# @ilovinarianag:
# rt
# @pbnrg:
# rt
# @dempstercbc:
# rt
# @bigdaddyluna_:
# @vincimike
# @cnn:
# rt
# @bbuzz33:
# @nmoralesnbc
# @primerdesignltd
# rt
# @tfee16
# @capgaznews:
# rt
# @daughtaofbiafra:
# @tersestuff:
# @pmharper
# rt
# @viscardi366:
# rt
# @��_
# ���@harolditz:
# @adamcurry
# @kyayaarkuchbi:
# rt
# @rt_america:
# rt
# @cameronciletti
# @tigersjostun
# (@
# @hempoilcures:
# @weathertrek
# rt
# @moeyjan:
# rt
# @bai_haay:
# rt
# @thomasbarker86
# @peytonshead
# @pupmemes:
# rt
# @bmiddy14:
# rt
# @ericfrancis:
# rt
# @zettieleeuw
# @alexyudelson:
# rt
# (@
# @daevi
# @thequint
# @sardesairajdeep
# @theprojecttv:
# rt
# @maryamnsharif
# @geonews_english
# @undp
# @aworldatschool
# @ajenglish
# @globalgrind:
# rt
# rt
# @lucievamps:
# @7newsbrisbane:
# rt
# @jimmustian:
# rt
# @example
# @homeloanking:
# @tonyabbottmhr
# rt
# @kaderaid_
# @rachzeed
# @candiceglover
# @carlbialik:
# rt
# @ab_tb_finance:
# rt
# @globalparker:
# @globalcalgary
# @n8luit
# rt
# @jovanhy369:
# rt
# @bbctrending:
# rt
# @emmadaly:
# @joeamon
# @hrw
# rt
# @asapzeek:
# @bloombergnews:
# rt
# @drsanjaygupta:
# rt
# @yaboi_c
# @alyssa_spano
# @mlb:
# rt
# @iiiuminateavery:
# rt
# @nickjonasworld:
# rt
# @jeffbezos
# @audible_com
# @hrdive
# @labor_attorneys
# @fmlainsights
# @biggassswagbear:
# rt
# @ups
# @upshelp
# @realdonaldtrump
# @w
# @andrew_drinks
# @chrishallbeer
# @tabamatu
# @huffingtonpost
# @diocesewesttx:
# rt
# @lorr_kyree:
# rt
# @nypost:
# rt
# @undp:
# @shoko_takemoto
# @undp_pacific
# rt
# @bunewsservice
# @brad_eveleigh:
# rt
# @salmanmydarling
# @wordpressdotcom
# @gofundme
# @hamizaaah
# @gilmanrocks7
# @sunrenatogandia:
# rt
# @paigedenim
# @sofiebroden
# @
# @caroliner94
# @elaina23abc:
# rt
# @dfaspokesperson
# @namingthedead:
# rt
# @basementboi
# @habakure
# @drspacejunk
# @ccriadoperez
# @newsbreaker:
# rt
# @channelten
# @luttsy,
# @manutd
# @emilymcfcheslop
# @andreashae_
# @timtebow:
# @flgovscott
# rt
# @shanejnr82
# @googlecr
# @hiran_patel
# @rjscherwin
# “@mamababylove:
# @emergencyglobal:
# rt
# @kloveradio:
# rt
# rt
# @sosfirstaidbc:
# rt
# @reneerobynphoto
# @memgrizz:
# @memgrizz,
# @aa000g9
# @redcross
# rt
# @castleconnellbc
# @wsvn
# @flapanthers
# @caldwell16…
# @waleedno
# @imlaurenmcguire
# (@
# @massgeneralnews)
# @itsmojojoejoe:
# “@saielvi:
# rt
# @puneetarora82:
# rt
# @bg_indynews
# @proglegs:
# @eurekasue49
# @idrive
# rt
# @sophiegshore
# @keziah_harvey
# @ndtv:
# rt
# @convoyofhope:
# rt
# @wawam:
# rt
# @thedailybeast:
# rt
# @breakingstorm:
# @larimersheriff
# rt
# @de_persdienst
# (@
# @livingsafely:
# rt
# @tokyotech_en
# @morningsmaria
# @foxbusiness
# @ethicalman:
# rt
# @onenewsnz
# @stcom:
# @stcom
# rt
# \@cnn:
# @ashleighwalters
# @unisdr:
# rt
# @msnbcdisrupt:
# rt
# @arabianofelix
# @b_nicolee_xoxo:
# @newsbreaker:
# @saulgarzafox4
# rt
# @stormchaserskc
# @foursquare!
# @bostonglobe:
# rt
# “@yahoosg:
# rt
# @joseybauman:
# rt
# @scec:
# rt
# @pmoindia
# @coc_ayne
# @todayshow
# @invig
# @ahhhlicia_tudor:
# @speranza_buio
# @canadapostcorp
# @arvind_joshi
# @jasontaylor1979
# @wnyc
# @cindylouwho_2:
# rt
# @lubnamostafa1
# @hmahmoud11
# @imantotonji
# @rema_negash
# @inquirerdotnet:
# rt
# @davidicke
# @mailonline
# @mways:
# rt
# @abscbnnews
# @gmanews
# @
# @andrewkantarias
# @christomlin:
# rt
# @ap)
# @adaminoakland:
# rt
# @jessalovesmj:
# rt
# @ygwinner_a
# @kutvron:
# rt
# @huffpost
# @libertypr
# @lin_manuel
# @
# @sameerkhan:
# rt
# @zackryder
# @adriangrenier
# @royceybell
# @jjablonska:
# rt
# @lucypalladino
# @twcbreaking:
# @ambieno
# rt
# @theeconomist:
# rt
# @conarelli:
# rt
# @elcayouth:
# rt
# @sal_bravo_
# @heelsandracing
# @jakeacarpenter:
# rt
# @catcasselli:
# @yahoocanadanews:
# rt
# @ant89:
# rt
# @trilllifestyle_:
# @arianagrande
# @abc)
# (@
# @cimarsloverpr:
# @federation
# rt
# @johndcook:
# rt
# @indystar:
# @ryansmithtv:
# rt
# @rescue5
# @interaksyon
# @khariheru
# @mrswift99:
# rt
# @jamesbedell:
# rt
# @devon_breneman
# @greegreece
# @
# @potus
# @realdonaldtrump
# @youranonnews:
# rt
# @alvarofong:
# rt
# @pele:
# rt
# @gcnelson:
# @abcnews
# rt
# @youtube
# @reuters
# @doubdour
# @
# \@abscbnnews:
# @dennis_datu
# @robrfs:
# rt
# @semeunacte:
# rt
# @nealabarton:
# rt
# @ecowatch:
# @tcktcktck
# @climatesavers
# @‰û_
# rt
# @irshadrmz8:
# rt
# rt
# @tvchick13:
# rt
# @bhalomanush:
# rt
# @eviltai:
# @nbcbayarea
# rt
# @archforhumanity:
# rt
# @morehouse64
# ã¤ã³ã¬@hem_picbot:
# @21shidae:
# @bbcnewsasia:
# rt
# @stacefamily:
# rt
# @katycat4life1
# @slate
# rt
# @shristigee
# @janaraai
# @yodenis_
# @mrsmurryela:
# rt
# @thomasa56
# @rico_wde16
# @analees6
# @frolichstein:
# @aaeminfo
# @aaem
# @gsep_em
# @srrezaie
# rt
# @sherdilkhan7
# @yahooph:
# rt
# @
# @nathangielis
# @er_deu2e
# @anupkaphle:
# @ukfarmersreview
# @matt_morse1:
# @khqa
# @mediacrooks
# @thenewshour
# @unwomenaust:
# @abcnews
# rt
# @maggieleary
# @bbysunnyd:
# rt
# @changepilipinas
# @nbcnews
# rt
# @nashhmu
# @globalcalgary
# @gmanews:
# rt
# @stormpulse:
# rt
# @sophierebecca28
# @honestreporting:
# rt
# @adgpi:
# rt
# @erik_ryan
# @bunnykaikai
# @kissability
# @jett_bluee_4
# @fake_pmlee:
# rt
# @bayloreq
# @
# @barbi_twins:
# rt
# @alaynaself
# @jerroldmcgrath
# @msf_picturedesk
# @weatherchannel:
# @juliagillard
# @ffordaustralia
# @mrtys_official
# @jepsiee
# @vickersthomas
# @
# @shelovin_loose
# @tyleronemo:
# rt
# @bbcworld:
# rt
# @lenouvelobs
# @onlybern
# @abbassomji
# @bflowers24:
# @deehedderman
# @mimicaeu
# @ricooo_suaveeee:
# @michellel646
# @marissahyland
# @franktown:
# rt
# @cnnladavid:
# rt
# @skinnyboiflacko:
# @ajc:
# rt
# @hyde_brewing
# @
# @calitxgod:
# ���@taehoward05:
# @calitxgod
# @cabugi
# ...
# @incindia
# @proudhindus:
# rt
# @aflac
# @stevesilberman:
# @colossal
# rt
# @juliagillard
# @edd1819:
# @news5e
# rt
# @deadmau5
# @eliinperu
# @anandwrites:
# rt
# @disneyirh
# @pjmedia_com:
# rt
# @staten
# @gabbylicious6:
# @missandrist:
# rt
# @hamishnews:
# rt
# @rexhuppke:
# rt
# @improvasylum's
# @decappeal:
# rt
# @usatoday
# @wvasia:
# rt
# @barry_osborne:
# rt
# @timesnow
# @depe1894
# @ellliot_wood:
# rt
# @brranzz:
# rt
# @denverpost
# @jannarden:
# rt
# @delta
# @geee_ohhhh
# @petersmileyface
# @homunculusloikm
# @612brisbane
# @paulatics
# @mayormandel
# @yahoonews:
# @yahoophoto
# rt
# @westhompson777
# @ap
# @brianlehrer
# @gawker
# @nzdoctor_news
# @cloydrivers:
# rt
# (@
# @awesome__brenda:
# rt
# @arianneharn:
# rt
# @imtimwan:
# @shawinfo
# @shawhelp
# rt
# @peanutbitter_:
# rt
# @flp_family
# @lilytapusoa:
# rt
# @alexthadoneill5
# @dinnerwithjulie:
# rt
# @minhazmerchant
# @kenziemay29
# @ajenglish
# @kaceyalden
# @tinyshelcy:
# rt
# @_saymynameloud:
# @prisonplanet:
# rt
# @thevirdas:
# rt
# @milanimalik:
# rt
# @christackett:
# rt
# @centrase
# @telstra
# @ericingalla:
# @mmda
# rt
# @
# @weknowthedj:
# rt
# @pamkulik
# @karlasu2
# @tara_cat
# @musicgirl83
# @gigigraciette:
# rt
# @paulbrandt:
# @builditforward,
# rt
# @nytimes:
# rt
# @wenaefron
# @wsj:
# rt
# @bigtikafriend:
# rt
# @cnn
# rt
# @worldvisionph:
# @worldvisionde
# rt
# @mexicanarchist
# @afolkhero:
# rt
# @pentagonpressec:
# rt
# @breakingnews:
# @usgs
# rt
# @chilis
# @chic71smith
# @ha5an_:
# rt
# @qpsmedia:
# rt
# @ksushma140:
# rt
# @ibritjordan
# @unicefusa
# @puppetonia2
# @wfaaweather:
# rt
# @alicesare
# @soshifiers:
# rt
# @
# @kevinlien
# @wired
# @brendon956
# @newshour
# @
# “@onefeu:
# rt
# @r_betancourt7:
# @austinduff22
# @astroterry
# @roundsally:
# rt
# @takhaan:
# rt
# (@
# @longislanddance
# @miow45
# @tswan313
# @lennonparham
# @jessica_stclair
# @gilmoreguysshow
# @globaltvnews
# (@
# @rccevents)
# @ivanvalenzuela)
# @cbcalerts:
# rt
# @bulwark_ext:
# @nightrideraz
# rt
# @rickmuscles:
# rt
# (@
# @tastemycupcakee
# @smilefordaniel:
# rt
# @nki_e:
# @qaasimofficial
# @operationusa
# @latroyhawkins32
# @orebobby:
# rt
# @zekncashe:
# @kathrynhallpr
# @wsj
# @ascoa:
# @ericfarns
# rt
# @thealbertaride:
# @calgarypolice
# @cgyfirefighters
# @nenshi
# rt
# @j_lee30
# @kfc_colonel
# @s_c_
# @ase:
# “@ethanklapper:
# rt
# rt
# @deped_ph
# rt
# @rtimuzaffar:
# @arvindkejriwal
# rt
# @arlenedickinson
# rtrtrt@harly_96:
# @trainlined
# @acsengineers
# @kltv7
# @comedyandtruth
# rt
# @usgs:
# @usgs
# rt
# @morton4l
# @zeenews:
# rt
# @angeljabines:
# @imlolabashang:
# rt
# @lrhspur:
# rt
# ���@quannyskitz169:
# @newearthquake:
# @sstoneabc30:
# @abc30
# rt
# @sbaranski:
# @pmharper
# rt
# @waruikoohii
# @
# @usrealitycheck:
# rt
# @iprincekhyll:
# rt
# @zohrajavid:
# rt
# @alexanderhaxton:
# rt
# @lizaposarartist
# @msredwriting
# @gatorsfb:
# rt
# @seanchu4ward4:
# rt
# @wkyt
# @frdavidken
# @savethechildren:
# rt
# @huffpostteen:
# @ellendoughty
# @yegwine
# @ginger_zee:
# rt
# @cnni:
# rt
# @
# @johnreport:
# rt
# â€œ@nationalnurses:
# @wkyc
# @bogswbz:
# rt
# @kyleclark:
# rt
# @adamschofield22:
# @pigriverside
# @backatone000:
# rt
# @misszindzi:
# rt
# @gegelava
# @rjablan
# @iyyamarielouela
# @uhleesone
# @indiatoday
# @rapplerdotcom:
# rt
# @bbcbreaking
# @bbcworld
# @tweetnirizal:
# rt
# @wopizza
# @waymoflydenu
# @hayleyshammock
# @
# @antonyball:
# @jami_usa:
# rt
# @the
# @leablandeau
# @alisonlovelight:
# @solightd
# rt
# @therealestpablo
# @fyeahtheorossi
# @sutterink
# @realchriswebber
# @jessicahische:
# rt
# @greenpeace:
# rt
# @
# @iscoretds_17:
# rt
# @wild_lionx3
# @cityofcalgary:
# @calgaryparking
# rt
# @jeff14news:
# rt
# @leonuhhh
# @cupsaucerblog
# @vickihigham
# rt
# @rescueph:
# rt
# @wwos9
# @marionkoopmans:
# rt
# @chuckweinknecht
# @hilaryduff
# @etabori:
# rt
# @andie__o:
# @sboshmafu:
# rt
# rt
# @aguywhoquotes:
# rt
# @patriciazakhem:
# @redcrossdenver
# rt
# @rottentomatoes
# @last_eon
# @gawker
# @drelovesyou1:
# @courtnie_leann
# (@
# @jillyy_grum:
# @adellenaz
# @davidfrawleyved
# @cnn
# @foxnews
# @msnbc
# @abcnews:
# @detroitnews:
# @theatlanticwire
# rt
# @papa_john93:
# rt
# @jeffbradynpr:
# rt
# @we_are_the_mob:
# rt
# @drmikemurdock
# @kimpoyfeliciano:
# rt
# @westonsolutions
# @omahausace
# @salarmypeoria
# @salarmyeds
# @connerkent20
# @tagbillfish:
# rt
# @layseejay
# @350:
# rt
# @irrational_fan:
# rt
# @firehousenews:
# rt
# @crawfordloritts:
# rt
# @preeti_chopra2
# @chinmaykrvd
# @jnbaloch:
# @kaleeribaloch:
# rt
# @joykw5:
# rt
# @prosyn
# @po_st
# @paddyobrian86:
# @vanzperry:
# rt
# @brooksmatic:
# rt
# @bloombergnews
# @salansar1
# @un
# @jdubsbro
# @newsbreaker:
# rt
# @leessangsgfc:
# rt
# @ajtapariya
# @bouncybluegirl:
# rt
# @emilyjanemolloy
# @mmckinnonart:
# @glenbowmuseum
# rt
# @indecision:
# rt
# @firstpostin
# @
# @ifreakselena
# @ericccxminaj
# @erikveland
# @ancalerts:
# rt
# #yycflood@tourismcalgary
# @marcusnjie
# @shraddhakapoor:
# @rohanshrestha
# rt
# @shivhanatron:
# rt
# @pmoindia
# @vaish_red_devil
# @
# @meghanrae13
# @breathehotyoga
# @thereporters:
# rt
# @kacehughes:
# rt
# @timothywhalin:
# rt
# @carolinemanzo
# @nytimes:
# rt
# @q13fox
# @scottglenn93
# @mellychantal
# @colinmcgonnigal
# @maggie_reardon
# @cnet
# @
# @cuisinechateau
# @hikeski
# @pdriscolltbt:
# @christiefaber
# rt
# @j_thorow
# @shaneryanhere
# @lovehiphopvh1
# @weatherchannel
# @markiss94
# @emmerdale
# @gatewaypundit
# @militarydotcom
# @americanidol?!?!
# @ohteenquotes:
# rt
# @james_yammouni
# @gappistanradio:
# @indiantweeter
# @satanbhagat
# rt
# @volunteercal
# @andersoncooper:
# rt
# @abc's
# @paritosh2608:
# rt
# @carrollpark
# @smithcanteen
# ���@sashaagloria:
# @ukparliament
# @the_new_rome:
# â€œ@tedd4u:
# @vickydnguyen
# rt
# rt
# @dorseyshaw
# @cameron_wate
# @06bigtown
# @mobilepunch:
# rt
# @gr4sshopp3r
# @seanbattystv:
# rt
# @
# @homedepotcanada
# @childrnscottage
# @usatoday
# @nikerunning:
# rt
# @jane_dyson:
# @…
# rt
# @codysimpson
# @nypost:
# rt
# @cirque
# @liz4rd_of_oz
# @machinima_com
# @mombot
# @the_real_despo:
# rt
# @kuhoops
# @mizzou
# @dayglowluk:
# rt
# @forextrading_id
# @channel4news:
# rt
# @curtisking10:
# @dlsud:
# rt
# @michelledeidre
# @undp_pacific:
# @undpasiapac
# @undp
# rt
# @neverknownfacts:
# @vangsness
# @therealzswagg
# @ryanintheus:
# \@rt_com:
# @kcrg_firstalert
# “@jannagummo:
# @tonygmarshall
# @maskthedemons:
# @l_hizzle
# @rachel_murphy:
# rt
# @abc:
# rt
# (@dive
# @aeacey23
# @jocelynb81)
# @lstmnews:
# rt
# @thephilcoenen
# @mubasherlucman
# @suryaray
# â€œ@ariweather:
# @courtyardhotels
# @anupkaphle:
# rt
# @aha_1988
# @red1tweets
# @theofleury14
# @hayleyhhunt
# @lenniestapes:
# “@hurricannesandy:
# @rubbyjuice??
# rt
# @amaruuygun
# @jaemsodear
# @vudugrrrrl:
# rt
# @johnseach:
# @texasmonthly
# @melissa_ppi:
# rt
# @hugoamazing:
# rt
# @bbcbreaking:
# rt
# @mapuainstitute:
# rt
# @rawstory:
# @nhc_atlantic:
# rt
# @saltandpepper
# @narendramodi
# @ravishndtv
# @tca_tca
# @aintposs
# @newwaveoil
# @anokacounty:
# @sivarajahmn
# @bassamjaara
# @mousaalomar
# @emmettluvr1D35
# rt
# @ap:
# rt
# @wyomingseminary
# @baseball_jesus_:
# rt
# @summerdwizz
# @ibnlive
# @zeenews
# rt
# rt
# @youtube
# @
# @ayazlatifpalijo:
# rt
# @kpcc
# rt
# @theemobrago
# @newssundanmoran
# @cnn
# “@williamshatner:
# @rglover702:
# @702sydney
# rt
# @whatniall:
# rt
# rt
# @fred_rayford6
# @abisayowhatsup
# @who
# @unicef
# @gavi
# rt
# @breakingnews:
# @ntsb
# rt
# @loretta8_sop
# @amaliebenjamin;
# @wxchris2011:
# rt
# @federation:
# rt
# @factsionary:
# rt
# @roseland
# @sujeeeen
# @danialysa
# #fucksandy@aishabonitaaa
# @mammals_suck
# @nicolaconte
# @
# rt
# @jayretro718
# @marykissel:
# @australian
# rt
# @youranonnews
# @m_sullivan95
# @channelnewsasia:
# rt
# @realhotcullen
# @gourmae
# @bigdaddyelvin
# @birdingmagazine:
# rt
# @darionmckane
# @yvonnen_kvue:
# @davidschechter
# rt
# rt
# @kenstarrbaylor
# @billclinton
# @scejas:
# rt
# @ellebelle37
# @x_nicsantiaga:
# @hurricannesandy:
# rt
# rt
# @yabs20:
# @mellyricks09
# @
# rt
# @bbcscitech
# @naptualelle
# @jalynschneider
# @lamontearth
# @realstevem:
# @boulderrelief
# rt
# @forestryva:
# @txforestservice
# rt
# @envyseven
# @springsteensays:
# rt
# @nbcnightlynews:
# @twcbreaking:
# rt
# rt
# @standardkenya:
# rt
# @cbsnews:
# rt
# @bettemidler
# @abc13houston:
# rt
# @workersworld:
# rt
# @mommyknowz:
# @plumberlocal
# rt
# @calgarypolice:
# rt
# @660news:
# rt
# @caarlax
# (@cain's
# @addisonlaine
# @caylidawn4
# @infinite_enemy
# @cbsthismorning:
# rt
# @sir_fin:
# @unitedwaycgy:
# rt
# @prospect
# @tinateapot27
# @cmshehbaz:
# rt
# @lozolpls:
# rt
# rt
# @namelessyun
# @maggieegrace
# @marissadash:
# rt
# @dicksayschicago!
# @rivernorthchi…
# @wbishop1213:
# rt
# @ants_sneweather:
# rt
# @jimanning:
# rt
# @gr4sshopp3r
# @liberalease:
# @po_st
# rt
# @missjonelyn:
# rt
# @theatlanticwire:
# rt
# @paulatrotter:
# rt
# @flgovscott
# @devmatthieu
# (@
# @thetrudz:
# rt
# @therealgelfie
# @scinski
# @dunn_noah:
# rt
# @txemergencyprep:
# rt
# @tweetdeez757:
# rt
# @qldses:
# @a1d077:
# rt
# rt
# @prashantktm:
# rt
# @tagalogkowts:
# rt
# @jacquesloveall:
# rt
# @deanofcomedy:
# @thedailybeast
# rt
# @coachsturdivan1:
# rt
# @greentravelguru:\na li
# @derek_dipiet:
# rt
# @nadeemqasim_:
# rt
# @kathmandupost:
# rt
# @itslegzzyo
# @v4nu4tu
# @armorogod:
# @olliemilman:
# rt
# @brendonurie
# @manzoor
# @yunggoddessbeth
# @alshareefa_joly
# @sfchronicle
# @sfexaminer
# @jmr1944
# (@
# @americanair
# @desarizzle74:
# @sherylunderwood
# rt
# @lombardo_music:
# rt
# @global_defcon:
# rt
# @brittanie_renae
# rt
# @supportnmforpm:
# rt
# @dallasnewsphoto:
# @sharethis
# rt
# @bendierker
# @pitbull
# @missusa
# @shaymitch:
# @unicef
# rt
# @yougomarniecoco
# @calgaryherald:
# @lorrainehjalte
# rt
# @
# @sunrenatogandia:
# @jonvicremulla:
# rt
# @danyallstar15:
# rt
# @thetrudz:
# rt
# @moneymetalcakes:
# rt
# @ismokethefinest:
# rt
# @usatoday
# @davidschneider:
# rt
# @ohitseesha:
# rt
# @thelululife
# @jvsshow
# @proteinworld
# @waseemstark:
# rt
# @martysmithespn:
# rt
# @sgkwave:
# rt
# @natureskid
# @bm_
# @chriscollinsto
# @kwwl:
# rt
# @fernandoharin
# @srilanka
# @mirandalambert:
# rt
# @froknowsphoto
# @lraycraft
# @todayonline:
# rt
# @jeanr27
# @manila_bulletin
# ���@harriettestone:
# @wayward_okie
# rt
# @timesofindia:
# rt
# (@
# @brewsterspub)
# @paulettebleam
# (@
# @angellazychef:
# rt
# @dmon2112
# @c_t_morgan
# @loveabiii_xo
# @aussiiebelieber:
# rt
# @kathleenogrady:
# @buzzfeedjack:
# rt
# rt
# @albertaatnoon
# @vanonselenp
# @youtube
# @jacksonrathbone
# @ilickmysoles
# rt
# @iainmartin1
# @telegraph
# @channelnewsasia:
# rt
# @dbeworld:
# rt
# @channel4news:
# rt
# @ndtv:
# rt
# @blazingroselia
# @miloshandel
# @
# rt
# @cinziacimmino
# @kendras84
# @gabrielaneda
# @emilyrsutton
# @hari:
# rt
# @inklesspw
# rt
# @stalkingreedus
# @jenaryisasian
# @wwwbigbaldhead
# @austinmahone:
# rt
# @thatparawh0re
# @nba:
# @cbsmiami
# @stevesownacc:
# @swannydpm
# rt
# @sammi_teee
# @bostonglobe:
# rt
# @orderinthequart:
# rt
# @pipperthedipper
# @bobick:
# @a29midwest
# @mysterychurch,
# @cnn:
# rt
# @erosbonazzi
# @jesspurba:
# rt
# @reformedbroker:
# @meredithfrost:
# @vickydnguyen:
# rt
# rt
# @alyssa_zauderer
# @rich_kruse
# @debkmorrison
# @molly_murphy13
# @me_physio
# @jeffcanoy:
# rt
# @behfarj:
# rt
# @iamclareng
# @wave3news
# @sidepix
# @kmbreferee
# @rowaida_abdel:
# rt
# @redcrossny:
# @federation
# rt
# @supreme_corey:
# rt
# @ap:
# rt
# @honeebfly:
# @hasanzabriskie
# rt
# rt
# @time:
# @time_video)
# rt
# @shereemutton:
# @sutherlandrfs
# rt
# @channelnewsasia:
# rt
# @khaleejtimes:
# rt
# @gawker:
# rt
# @chris_lrawdog1:
# rt
# @youtube
# @solangeknowles:
# \“@realdonaldtrump:hurricane
# rt
# @businessinsider
# @jfranceska:
# rt
# @thegooglecar:
# rt
# @lexi_purduee
# @famousnobodies:
# rt
# @rescueph:
# @djkingassassin:
# rt
# @torindarkflight
# @chrisuscarves
# @
# @qpsmedia:
# rt
# @stevebruskcnn:
# rt
# @paygeers_t:
# rt
# @nbcdfwweather:
# rt
# @amarie05
# @obeyhazza:
# rt
# @alexwileman13
# @_foreverryoung:
# @imiyannax:
# @joejonas
# @bactiman63:
# rt
# @reveur_ktm:
# @dezzyybr:
# @reveur_ktm:
# @guardian:
# rt
# @kyoshino:
# rt
# @cp24:
# rt
# @volvooceanrace
# @glovesoffhockey
# @channel4news
# @millerc4
# @actalliance
# @usda:
# rt
# @gansevoortpark
# @wearedelasoul
# @katbastion:
# rt
# @jmonies:
# @jdsutter
# @sfagammas:
# rt
# @angelaehh:
# @comfort_calgary
# rt
# @meaindia
# @globeandmail:
# rt
# @washingtonpost
# @druhfarrell:
# rt
# @nohungerinyyc
# @miilkkk:
# rt
# @maltesemanor:
# @newstalk4bc
# rt
# @savannahprewitt:
# @molmstead3:
# rt
# @cityofcalgary:
# rt
# @
# @thejudsonjones
# @bhavatarini25:
# rt
# @ap:
# rt
# @jbcgiveaway
# @justinbieber
# @jbcrewdotcom
# @seomasterplan2:
# @youtube
# rt
# @elizabethh_xoxo
# @enmax:
# @gregmccarthy0,
# rt
# @timeworld
# @salmamalaeb:
# rt
# @drcindyhaines:
# rt
# @sarahjla
# @dxzone:
# rt
# @bam__margera
# @jwow1227
# @remindhq
# @
# @essel1
# @alaskaair
# @yahoonews:
# rt
# ���@ust_csc:
# @infineightyy:
# rt
# @sharethis
# @kenneyjason
# @kinmrene
# @wlfhnter
# @infos140:
# @annemnry
# @jabezleal:
# rt
# rt
# @kimdivored
# @wgntv
# @skilling
# @abpnewstv:
# rt
# @nbcnightlynews:
# rt
# rt
# @carolineartiss
# @camerondallas
# @e_laumea
# @saintlysammi
# @660news:
# rt
# @mbitakyan:
# rt
# @ancalerts:
# rt
# @awesometreasure:
# rt
# @verrit
# @ecdc_msprenger:
# rt
# @thehill
# @khandanish_
# @farhankvirk
# @
# @jonginugh
# @yeg_ron
# @carinatplan
# @alkazaaan
# @onoyra
# @jchannon
# @bentayloruk
# @braden_bush2312
# @_saymynameloud:
# @lemieuxlgm:
# rt
# @volunteerhoward:
# @nationalvoad
# rt
# @ania_natalia33
# @todayonline:
# rt
# @damiaanactie
# @
# @huffingtonpost:
# rt
# @
# @ahurricanesandy:
# rt
# @ecoteneo
# @alqalaminst
# @mussol22
# @joeltaborasj
# @mindanews2010
# @facelessnyc:
# rt
# @
# @perezhilton:
# @barackobama
# rt
# @
# @corleonedaboss
# @thechristinakim
# @gaemar01:
# @gofundme
# @ashton5sos
# @brielle1101
# @sizzxo
# @lilmeady:
# rt
# @wordsbyamna
# @adamtuss
# @bro_vik:
# rt
# @nycjim:
# “@njerzyfirealert:
# @pzfeed
# rt
# @thatscribbler
# @randy_foster
# @savechildrenuk:
# rt
# @_jmterrado
# @bbcbreaking:
# rt
# @e_the_man121
# @care:
# rt
# @nbc12:
# rt
# @jtimberlake:
# @thetnkids
# rt
# @factssboutstuff:
# rt
# @timehealth:
# rt
# @ryan
# @julianbc6
# @nbc6
# @abbywildfire
# @xdipetta:
# @gundrukpost:
# @gasebtandin
# rt
# @willkane:
# rt
# @charlesadler
# @janbrixx:
# rt
# @concord_europe:
# @dochasnetwork
# rt
# @robbiegvt
# @mackayim:
# rt
# @luccadoes:
# rt
# @femaleturnons:
# @ndtv:
# rt
# @haych_enn
# @bbcnews:
# rt
# @saucierkmkaren
# @swiftycommissh
# @taoistinsight
# @immortaltech
# @mikaylaxo3:
# @wizz_cherifa
# rt
# @squarespace
# @kavkazcenter:
# rt
# @that_fat_guy
# @footjoy
# @tiemsin:
# @jssalceda
# @savechildrenph
# rt
# @wired
# @vicehoodnews:
# rt
# @wpix:
# rt
# @buzzfeednews:
# (@bostonglobe)
# rt
# @donaldallen23:
# @nasa:
# rt
# @klaszus:
# @nmc_canada
# @calgarylibrary
# rt
# @austinmahone
# @govbrewer:
# rt
# @roseannaavento
# @jackkinross
# @annphiboly:
# rt
# @sunstarcebu
# @cebugovph
# @cebudailynews
# @veco_cebu
# @sunrenatogandia:
# rt
# @sirmecmec:
# rt
# @only1marcello
# @bias_sports
# @katiecouric:
# rt
# @huffpostgay
# @nhl:
# rt
# @fotboyzinc:
# @heavyoilcountry
# rt
# @dudeeitsbree:
# \“@xmissbliss:
# @thomasjsmison
# @bbcbreaking:
# rt
# @davidschechter:
# rt
# @nathanthewanted
# @jaythewanted
# @somethinmajor94:
# rt
# @nigeriaportal
# @bbcbreaking:
# rt
# @danivelasco28:
# rt
# @newsbreaker:
# (@passantino)
# rt
# @ginalimp:
# rt
# @davidbegnaud
# @lethsnews:
# rt
# @bmcnoldy:
# rt
# @volunteercal:
# rt
# rt
# @stvlynne:
# rt
# @
# @bradsucks:
# rt
# @wsbtv
# @kiddwwe:
# rt
# @upi
# @jadinediary:
# rt
# @envw98
# @nickcocofree
# @juliedicaro
# @jdabe80
# @laracarbonara:
# @bbcbreaking1h
# rt
# rt
# @basicallystacey:
# â€œ@toptrendww:
# rt
# @beastbiz:
# rt
# @foxnews:
# @dna:
# rt
# @cjredwine:
# rt
# @depresseddarth:
# rt
# @_tattedbeautyy:
# rt
# “@ac360:
# rt
# ���@krizzy_kalerqui:
# @simonsaxby
# @soulpancake
# @naomilatu
# @met2art:
# @doctorow
# rt
# @joelski_luv
# @duece_vale
# @matthewgange
# @dannyjohnjules
# @spencer_fearon
# @christielinford
# @basketballpics:
# @patycantu:
# rt
# @missleylaha
# @zello
# @reutersus
# rt
# @
# @tmfk_co
# @_chammond
# @jajajajastinly:
# rt
# @michellemalkin:
# rt
# @forbes:
# rt
# @bbcworld:
# rt
# @themindblowing:
# rt
# @cabtogo:
# @cbsnews
# @redcross
# rt
# @belieberswagguh:
# rt
# @brandynfoster
# @mortonlb53
# rt
# @amandaash:
# @taylorswift13
# rt
# @coreyetter:
# @joerogan
# rt
# @smyth94ever
# @gfour_84:
# rt
# @d_orton33:
# rt
# @officcialmunti:
# rt
# @name_janedoe
# @whitegurl_nikki
# @bkabak
# @loyolagil
# @ahs_southzone:
# rt
# @ndtv
# @luv2livelyf
# @tanishaa_
# @yourrocketina:
# rt
# @breakingnews:
# rt
# @christsavageazz:
# @calibweaver
# @rrobinson489
# @bonn1egreer:
# rt
# @crmanofsteel
# @khloekardashian:
# rt
# @sharan070192:
# rt
# @antderosa:
# rt
# @policy
# @kellylshinn
# @channelnewsasia:
# rt
# @its_kelsee
# @savannahmay34:
# @travisdwatson
# @icrc:
# rt
# @mar_aldana_:
# rt
# @jerutter:
# @audubonmagazine
# rt
# @cws_global:
# rt
# @breakfast1015:
# rt
# @rockandrawhide
# @petcofoudation
# (@
# @webroot:
# @webroot
# rt
# @
# @grenfell
# @stoolpresidente:
# @melanie_stamey
# @phuonglazie
# @redcrossdallas:
# rt
# @simply__elaine
# @ebonycavallaro
# @cnnbrk:
# rt
# @mauds99
# @jagexsupport
# @kingsalman
# @barackobama
# @masbatecity
# @sednonsatiata:
# @nrberlanga:
# rt
# rt
# @hillaryrosner:
# rt
# @harperswine
# @mingna:
# @att,
# @tmo‰û_
# rt
# @republicofchadd
# @escott94
# @rkarnad:
# rt
# @dontcr0ssmypath
# @palmerhusky
# @youtube
# @dutchsinse
# @diversion2006
# @janmaree98
# @jewelsparkle3
# @vassa42
# @albertlt74
# @tiwigirl
# @ascottgr
# @havenr64
# @brnfst
# @prismodart
# @lisa_keeno
# @wunderground:
# rt
# @seriousnoonie
# @itweetwtfiiwant:
# rt
# @wvunews
# hurt@anthonyeusebio:
# @erinnanov:
# rt
# @newscientist:
# rt
# @cbssports:
# rt
# @homeworldgym
# @thisisperidot
# @karakaty18
# @itvnews:
# rt
# @centexredcross:
# rt
# @camillal33
# ���@rapplerdotcom:
# @visayans
# @letsmakeadeal
# @hellerweather:
# rt
# @ameeeeet1
# @womenintheworld
# @laurenfleshman
# @flotrack
# @scottyday
# @x0iar:
# rt
# @great_one_:
# @usatoday
# @jeffreyguterman:
# @vickydnguyen:
# rt
# @abc7newsbayarea:
# @vicleeabc7
# rt
# @nwi_jsp:
# rt
# @deb117
# @eduability
# @davos
# @epn
# @buzzfeedandrew
# @globeandmail:
# @juliebishopmp:
# @peterdutton_mp
# @who
# @…
# rt
# @lamontearth's
# @nbcnews:
# @jasonvanrassel:
# @wildrosebrewery
# rt
# @worldvisionph
# @geogabout:
# rt
# @sherrysamples:
# rt
# @angpoetnyo:
# @darrenhayes
# @deucee_treyy
# @seharsaleem:
# @eaamâ€¦
# rt
# @flatiron
# @bbcnewsasia
# @m_s_kendrick:
# rt
# @area51org:
# rt
# @klovenews:
# rt
# @franyafranya:
# @rqskye:
# @
# @sclerodharma
# @redcross
# @guardianus:
# rt
# @metrolink
# @smitharyy:
# rt
# @huffpostgreen:
# rt
# @yahooph:
# @incredivince:
# rt
# rt
# @_iamyourdestini
# @kananaskisgolf
# @melibrewer_22
# @thehill:
# rt
# @earlofgc:
# @globalcalgary:
# @milesmcpherson:
# rt
# @itvnews:
# rt

# %% [markdown]
# #### Learning how to do some text stuff

# %%
# proc_list = []
# for i, df in enumerate(df_list):
#     print("processing: "+ df_list_name[i])
#     df['processed_txt'] = process(df['text'])
#     print("processing: "+ df_list_name[i] + " complete")
# Out:
# processing: combinedf
# processing: combinedf complete
# processing: train
# processing: train complete
# processing: test
# processing: test complete
# processing: dev
# processing: dev complete

# %%
combinedf.head()
# Out:
#                    id                     event                      source  \
# 0                 530           disaster_events  drd-figureeight-multimedia
# 1  913070034204884992           hurricane_maria                   crisismmd
# 2  540027128478044160  2014_philippines_typhoon                crisisnlp-cf
# 3               17711           disaster_events  drd-figureeight-multimedia
# 4           778251007           disaster_events                      dsm-cf
#
#                                                 text lang  lang_conf  \
# 0  Organization that are working in Haiti, I do n...   en   1.000000
# 1  Maria now a hurricane again!! Strong storm sur...   en        NaN
# 2  RT @ANCALERTS: Fallen tree branches scattered ...   en   0.950529
# 3  The Government did not request international a...   en   1.000000
# 4  Remove http://t.co/77b2rNRTt7 Browser Hijacker...   en   1.000000
#
#        class_label  event_cat  class_label_cat  \
# 0      informative         54                0
# 1      informative         57                0
# 2      informative         47                0
# 3      informative         54                0
# 4  not_informative         54                1
#
#                                        processed_txt
# 0  organization that are working in haiti i do no...
# 1  maria now a hurricane again !! strong storm su...
# 2  fallen tree branches scattered in sorsogon cit...
# 3       the government did not request international
# 4                        remove browser hijacker how

# %%
"@" in combinedf.text
# Out:
# False

# %%
sub ='@'
  
# creating and passsing series to new column
combinedf[combinedf["text"].str.find(sub) >=1]
# Out:
#                        id                         event        source  \
# 2      540027128478044160      2014_philippines_typhoon  crisisnlp-cf
# 6      508334135531036672          2014_pakistan_floods  crisisnlp-cf
# 11     262727750723461120  2012_sandy_hurricane-ontopic   crisislext6
# 15     324278741322846208  2013_boston_bombings-ontopic   crisislext6
# 20     909451477944594434                hurricane_irma     crisismmd
# ...                   ...                           ...           ...
# 15863  904780153242361856              hurricane_harvey     crisismmd
# 15865  324777811611103233               2013_west_texas   crisislext6
# 15867  350036929837940736   2013_alberta_floods-ontopic   crisislext6
# 15868  324755102143504385     2013_west-texas_explosion  crisislext26
# 15869  591903388817870848         2015_nepal_earthquake  crisisnlp-cf
#
#                                                     text lang  lang_conf  \
# 2      RT @ANCALERTS: Fallen tree branches scattered ...   en   0.950529
# 6      RT @NewPakistan2020: Chiniot Flood Relief Camp...   en   1.000000
# 11     Plum ice cream is back! Yes! (@ The Meatball S...   en   1.000000
# 15     RT @mayortommenino: To assist victims of the #...   en   1.000000
# 20     RT @michaelbeatty3: SHEP ON A SUNDAY? NO THANK...   en        NaN
# ...                                                  ...  ...        ...
# 15863  RT @thehill: "Trump’s climate policy legacy wi...   en        NaN
# 15865  LMAO @EarLofGC: Another explosion in the US at...   en   1.000000
# 15867  why am I not surprised?! @GlobalCalgary: UPDAT...   en   1.000000
# 15868  RT @milesmcpherson: #PrayforTexas #PrayforWest...   en   0.955656
# 15869  RT @itvnews: RAF C-17 aircraft loaded with vit...   en        NaN
#
#            class_label  event_cat  class_label_cat  \
# 2          informative         47                0
# 6          informative         46                0
# 11     not_informative          8                1
# 15         informative         18                0
# 20     not_informative         56                1
# ...                ...        ...              ...
# 15863      informative         55                0
# 15865      informative         36                0
# 15867      informative         13                0
# 15868      informative         35                0
# 15869      informative         50                0
#
#                                            processed_txt
# 2      rt ancalerts fallen tree branches scattered in...
# 6      rt newpakistan2020 chiniot flood relief camps ...
# 11     plum ice cream is back ! yes ! the meatball sh...
# 15     rt mayortommenino to assist victims of the #bo...
# 20     rt michaelbeatty3 shep on a sunday ? no thanks...
# ...                                                  ...
# 15863  rt thehill trump’s climate policy legacy will ...
# 15865  lmao earlofgc another explosion in the us at a...
# 15867  why am i not surprised ?! globalcalgary update...
# 15868  rt #prayfortexas #prayforwest continue to #pra...
# 15869  rt itvnews raf c 17 aircraft loaded with vital...
#
# [41538 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
# df_list_name = ['combinedf','train', 'test', 'dev']

cv = CountVectorizer()

train_counts = cv.fit_transform(df_list[1]['processed_txt'])
test_data = cv.transform(df_list[2]['processed_txt'])

nb = MultinomialNB()

clf = nb.fit(train_counts, df_list[1]['class_label'])
predicted = clf.predict(test_data)


print("NB prediction accuracy = {0:5.1f}%".format(100.0 * clf.score(test_data, df_list[2]['class_label'])))
# Out:
# NB prediction accuracy =  82.3%

# %%
# Read about Pipelines here:
# http://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html
from sklearn.pipeline import Pipeline

tools = [('cv', CountVectorizer()), ('nb', MultinomialNB())]
clf = Pipeline(tools)

clf = clf.fit(df_list[1]['processed_txt'], df_list[1]['class_label'])
predicted = clf.predict(df_list[2]['processed_txt'])

print("NB prediction accuracy = {0:5.1f}%".format(100.0 * clf.score(df_list[2]['processed_txt'], df_list[2]['class_label'])))
# Out:
# NB prediction accuracy =  82.3%

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tools = [('tf', TfidfVectorizer()), ('nb', MultinomialNB())]
clf = Pipeline(tools)

# set_params() of TfidfVectorizer below, sets the parameters of the estimator. The method works on simple estimators as 
# well as on nested objects (such as pipelines). The pipelines have parameters of the form <component>__<parameter> 
# so that it’s possible to update each component of a nested object.
clf.set_params(tf__stop_words = 'english')

clf = clf.fit(df_list[1]['processed_txt'], df_list[1]['class_label'])
predicted = clf.predict(df_list[2]['processed_txt'])

print("NB (TF-IDF with Stop Words) prediction accuracy = {0:5.1f}%".format(100.0 * clf.score(df_list[2]['processed_txt'], df_list[2]['class_label'])))
# Out:
# NB (TF-IDF with Stop Words) prediction accuracy =  80.1%

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tools = [('tf', TfidfVectorizer()), ('nb', MultinomialNB())]
clf = Pipeline(tools)

# set_params() of TfidfVectorizer below, sets the parameters of the estimator. The method works on simple estimators as 
# well as on nested objects (such as pipelines). The pipelines have parameters of the form <component>__<parameter> 
# so that it’s possible to update each component of a nested object.
clf.set_params(tf__stop_words = 'english')

clf = clf.fit(df_list[1]['processed_txt'], df_list[1]['class_label'])
predicted = clf.predict(df_list[2]['processed_txt'])

print("NB (TF-IDF with Stop Words) prediction accuracy = {0:5.1f}%".format(100.0 * clf.score(df_list[2]['processed_txt'], df_list[2]['class_label'])))
# Out:
# NB (TF-IDF with Stop Words) prediction accuracy =  80.1%

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfTransformer

clf = Pipeline([('vect', CountVectorizer(stop_words = 'english')),
                ('tfidf', TfidfTransformer()),
                ('lr', LogisticRegression())])


clf = clf.fit(df_list[1]['processed_txt'], df_list[1]['class_label'])
predicted = clf.predict(df_list[2]['processed_txt'])
# predicted_geo_lab = clf.predict(geotweets['processed_txt'])
# geotweets['predict']=predicted_geo_lab

print("LR (TF-IDF with Stop Words) prediction accuracy = {0:5.1f}%".format(100.0 * clf.score(df_list[2]['processed_txt'], df_list[2]['class_label'])))
# Out:
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LR (TF-IDF with Stop Words) prediction accuracy =  85.4%

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn import metrics

tools = [('cv', CountVectorizer()), ('lr', LogisticRegression())]
pclf = Pipeline(tools)


# Lowercase and restrict ourselves to about half the available features
pclf.set_params(cv__stop_words = 'english', \
                cv__ngram_range=(1,3), \
                )

pclf.fit(df_list[1]['processed_txt'], df_list[1]['class_label'])
y_pred = pclf.predict(df_list[2]['processed_txt'])
print(metrics.classification_report(df_list[2]['class_label'], y_pred, target_names = ['informative','not']))
# Out:
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#  informative       0.89      0.87      0.88     18626
#          not       0.82      0.84      0.83     12469
#
#     accuracy                           0.86     31095
#    macro avg       0.85      0.86      0.85     31095
# weighted avg       0.86      0.86      0.86     31095

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn import metrics

tools = [('cv', CountVectorizer()), ('nb', MultinomialNB())]
pclf = Pipeline(tools)


# Lowercase and restrict ourselves to about half the available features
pclf.set_params(cv__stop_words = 'english', \
                cv__ngram_range=(1,2), \
                )

pclf.fit(df_list[1]['processed_txt'], df_list[1]['class_label'])
y_pred = pclf.predict(df_list[2]['processed_txt'])
print(metrics.classification_report(df_list[2]['class_label'], y_pred, target_names = ['informative','not']))
# Out:
#               precision    recall  f1-score   support
#
#  informative       0.80      0.93      0.86     18626
#          not       0.86      0.66      0.75     12469
#
#     accuracy                           0.82     31095
#    macro avg       0.83      0.79      0.80     31095
# weighted avg       0.83      0.82      0.82     31095

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn import metrics

tools = [('cv', CountVectorizer()), ('nb', MultinomialNB())]
pclf = Pipeline(tools)


# Lowercase and restrict ourselves to about half the available features
pclf.set_params(cv__stop_words = 'english', \
                cv__ngram_range=(1,3), \
                cv__lowercase=True, \
                cv__min_df=2, \
                cv__max_df=0.5)

# pclf.fit(mvr_train, y_train)
# y_pred = pclf.predict(mvr_test)
# print(metrics.classification_report(y_test, y_pred, target_names = mvr.target_names))

pclf.fit(df_list[1]['processed_txt'], df_list[1]['class_label'])
y_pred = pclf.predict(df_list[2]['processed_txt'])
print(metrics.classification_report(df_list[2]['class_label'], y_pred, target_names = ['informative','not']))
# Out:
#               precision    recall  f1-score   support
#
#  informative       0.86      0.85      0.86     18626
#          not       0.78      0.80      0.79     12469
#
#     accuracy                           0.83     31095
#    macro avg       0.82      0.82      0.82     31095
# weighted avg       0.83      0.83      0.83     31095

# %%
# Extract the classifier
clf = pclf.steps[1][1]
print('Number of Features = {}'.format(clf.feature_log_prob_.shape[1]))
# Out:
# Number of Features = 134001

# %% [markdown]
# Ideas for improvement
#     - a good natural disaster corpus to run as a vocablulary
#     - meaningful stop words

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import os, sys
import itertools
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import scale, LabelBinarizer
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn import metrics
# Random seed for numpy
np.random.seed(18937)

# %%
X = combinedf.processed_txt
y = combinedf.class_label_cat
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, 
                                                    random_state = 42, shuffle = True, 
                                                    stratify = y)

tools = [('tfidf', TfidfVectorizer()), ('lr', LogisticRegression())]
clf = Pipeline(tools)
clf.set_params(tfidf__stop_words = 'english')

# Build DTM and classify data
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("Confusion Matrix")
print(confusion_matrix(y_test, y_pred))
print("Classification report")
print(classification_report(y_test, y_pred))
print("Crossvalidation report")
print(cross_val_score(clf, X_train, y_train, cv=5))
print(metrics.classification_report(y_test, y_pred, target_names = ['informative','not']))
# Out:
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Confusion Matrix
# [[24681  3442]
#  [ 3774 15025]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87     28123
#            1       0.81      0.80      0.81     18799
#
#     accuracy                           0.85     46922
#    macro avg       0.84      0.84      0.84     46922
# weighted avg       0.85      0.85      0.85     46922
#
# Crossvalidation report
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.84714801 0.84710234 0.85043613 0.84865507 0.84928754]
#               precision    recall  f1-score   support
#
#  informative       0.87      0.88      0.87     28123
#          not       0.81      0.80      0.81     18799
#
#     accuracy                           0.85     46922
#    macro avg       0.84      0.84      0.84     46922
# weighted avg       0.85      0.85      0.85     46922

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
X = combinedf.processed_txt
y = combinedf.class_label_cat
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, 
                                                    random_state = 42, shuffle = True, 
                                                    stratify = y)

tools = [('tfidf', TfidfVectorizer()), ('nb',  MultinomialNB())]
clf = Pipeline(tools)
clf.set_params(tfidf__stop_words = 'english',
#               sgdc__alpha = 0.001,
#               sgdc__max_iter = 75,
#               sgdc__n_jobs = -1)
              )

# Build DTM and classify data
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))
print("\nCrossvalidation report")
print(cross_val_score(clf, X_train, y_train, cv=5))
print(metrics.classification_report(y_test, y_pred, target_names = ['informative','not']))
# Out:
# Confusion Matrix
# [[26266  1857]
#  [ 7581 11218]]
#
# Crossvalidation report
# [0.79905923 0.79673015 0.80001827 0.80239302 0.7995981 ]
#               precision    recall  f1-score   support
#
#  informative       0.78      0.93      0.85     28123
#          not       0.86      0.60      0.70     18799
#
#     accuracy                           0.80     46922
#    macro avg       0.82      0.77      0.78     46922
# weighted avg       0.81      0.80      0.79     46922

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers import Dense, Input, Dropout
from keras import Sequential

# %%
X = combinedf.processed_txt
y = combinedf.class_label_cat
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, 
                                                    random_state = 42, shuffle = True, 
                                                    stratify = y)

# %%
def create_model(optimizer="adam", dropout=0.1, init='uniform', nbr_features=2500, dense_nparams=256):
    model = Sequential()
    model.add(Dense(dense_nparams, activation='relu', input_shape=(nbr_features,), kernel_initializer=init,)) 
    model.add(Dropout(dropout), )
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=optimizer,metrics=["accuracy"])
    return model

# %%
kears_estimator = KerasClassifier(build_fn=create_model, verbose=1)

# %%
estimator = Pipeline([("tfidf", TfidfVectorizer(analyzer ="word", 
                                                stop_words='english',
                                               )), 
                       ('ss', StandardScaler(with_mean=False,)), 
                       ("kc", kears_estimator)])

# %%
param_grid = {
    'tfidf__ngram_range': [(1,1), (1,2), (2,2), (1,3)],
    'tfidf__use_idf': [True, False],
    'kc__epochs': [10, 100, ],
    'kc__dense_nparams': [32, 256, 512],
    'kc__init': [ 'uniform', 'zeros', 'normal', ], 
    'kc__batch_size':[2, 16, 32],
    'kc__optimizer':['RMSprop', 'Adam', 'Adamax', 'sgd'],
    'kc__dropout': [0.5, 0.4, 0.3, 0.2, 0.1, 0]
}

# %%
kfold_splits = 5
grid = GridSearchCV(estimator=estimator,  
                    n_jobs=-1, 
                    verbose=1,
                    return_train_score=True,
                    cv=kfold_splits,  #StratifiedKFold(n_splits=kfold_splits, shuffle=True)
                    param_grid=param_grid,)

# %%
grid_result = grid.fit(X, y, ) #callbacks=[tbCallBack]

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 5 folds for each of 10368 candidates, totalling 51840 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 153, in _feed
#     obj_ = dumps(obj, reducers=reducers)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/externals/loky/backend/reduction.py", line 271, in dumps
#     dump(obj, buf, reducers=reducers, protocol=protocol)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/externals/loky/backend/reduction.py", line 264, in dump
#     _LokyPickler(file, reducers=reducers, protocol=protocol).dump(obj)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/externals/cloudpickle/cloudpickle_fast.py", line 563, in dump
#     return Pickler.dump(self, obj)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/_memmapping_reducer.py", line 442, in __call__
#     for dumped_filename in dump(a, filename):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/numpy_pickle.py", line 480, in dump
#     NumpyPickler(f, protocol=protocol).dump(value)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/pickle.py", line 487, in dump
#     self.save(obj)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/numpy_pickle.py", line 279, in save
#     wrapper.write_array(obj, self)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/numpy_pickle.py", line 103, in write_array
#     pickler.file_handle.write(chunk.tobytes('C'))
# OSError: [Errno 28] No space left on device
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# <ipython-input-23-022c31fc48be> in <module>
# ----> 1 grid_result = grid.fit(X, y, ) #callbacks=[tbCallBack]
#       2
#       3 # summarize results
#       4 print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#       5 means = grid_result.cv_results_['mean_test_score']
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1286     def _run_search(self, evaluate_candidates):
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#    1290
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# PicklingError: Could not pickle the task to send it to the workers.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

# Build a mode that is composed of this list of layers
model = Sequential(
    [
          # This specifies a single neuron, and the input is 2 numbers.
    Dense(1, input_dim=2),  # a dense layer, every neuron is connected to all points from the lower layer (input)
    Activation('linear'),   # Specify the type of decision surface, i.e., simple linear regression
    Dense(1),               # another dense layer, input_dim is inferred from the previous layer's output
    Activation('sigmoid')   # Specify the type of decision surface, i.e., simple logistic regression
    ]
)
model.summary()

# %%
n = 9
message = english.iloc[n]['text']
message_procc =  preproccessed_tweets [n]
print(message)
print(message_procc)

# %%
# Accumulate counts of tokens, using string functionality


# Used to print sequences in a nice manner

pp = pprint.PrettyPrinter(indent=2, depth=2, width=80,compact=True)

# Tokenize the message and create a counter for frequency of each word in message.
# Browse for split() python or go to this link http://www.pythonforbeginners.com/dictionary/python-split to see what split() does
words = message.split()
word_count = col.Counter(words)

# Setting the limit to 40 for the number of tokens to display 
counts_to_display = 40

# Display results. 
print('Total number of tokens = {0}'.format(len(word_count)))
print(30*'-')
print('Top {} tokens by frequency:'.format(counts_to_display))
print(30*'-')
pp.pprint(word_count.most_common(counts_to_display))

# %%
# Accumulate counts of tokens, using string functionality


# Used to print sequences in a nice manner

pp = pprint.PrettyPrinter(indent=2, depth=2, width=80,compact=True)

# Tokenize the message and create a counter for frequency of each word in message.
# Browse for split() python or go to this link http://www.pythonforbeginners.com/dictionary/python-split to see what split() does
words = message_procc.split()
word_count = col.Counter(words)

# Setting the limit to 40 for the number of tokens to display 
counts_to_display = 40

# Display results. 
print('Total number of tokens = {0}'.format(len(word_count)))
print(30*'-')
print('Top {} tokens by frequency:'.format(counts_to_display))
print(30*'-')
pp.pprint(word_count.most_common(counts_to_display))

# %%
words = message.lower().split()
word_count = col.Counter(words)

# Setting the limit to 40 for the number of tokens to display 
counts_to_display = 40

# Display results. 
print('Total number of tokens = {0}'.format(len(word_count)))
print(30*'-')
print('Top {} tokens by frequency:'.format(counts_to_display))
print(30*'-')
pp.pprint(word_count.most_common(counts_to_display))

# %%
twks= twokenize.tokenizeRawTweetText(message)
word_count = col.Counter(twks)
# Setting the limit to 40 for the number of tokens to display 
counts_to_display = 40

# Display results. 
print('Total number of tokens = {0}'.format(len(word_count)))
print(30*'-')
print('Top {} tokens by frequency:'.format(counts_to_display))
print(30*'-')
pp.pprint(word_count.most_common(counts_to_display))

# %%
# In the below print statememt, {0:12s} means, print argument 1 with 12 spaces allocated for it. 
# You can see that for two of the results, 12 spaces is not adequate and these results are misaligned.
print('{0:12s}: {1}'.format('Term', 'Frequency'))
print(20*'-')

total_word_count = sum(word_count.values())
for count in word_count.most_common(counts_to_display):
    pp.pprint('{0:12s}: {1:4.3f}'.format(count[0], count[1]/total_word_count))

# %%
cv = CountVectorizer(analyzer='word', lowercase=True)\
cv.fit(english['text'])

# %%
# We can now process documents.

# We need an iteratable to apply cv.transform()
msg = []
msg.append(message)

# Transforming a single message is easier to comprehend. By default, scikit learn uses sparse matrices for text processing
# It returns a Document Term Matrix (dtm)
dtm = cv.transform(msg)

# In sparse format number of tokens indicate size of dataset vocabulary. 
# So there is 1 document and 130107 featues in the dtm.
print('Number of Samples = {0}'.format(dtm.shape[0]))
print('Number of Tokens = {0}'.format(dtm.shape[1]))
print(80*'-')


# You can't explore the document-term matrix when it is in sparse form. We can convert from sparse to dense form to explore 
# the document-term matrix. The range given below is chosen randomly. 
# Each word is a feature. Below zeros indicate the words/features in columns 1000 to 1100, those words do not appear in 
# the input message. Thats why we have zeros for those cells
print(dtm.todense()[:,1000:1100])
print(80*'-')


# We can also print only nonzero DTM matrix elements. 
print('Cells from Document-Term Matrix[i, j] and c (Count)')
print(80*'-')



# Find non-zero elements. scipy.sparse.find() returns the indices and values of the nonzero elements of a matrix.
# i,j contains the row and column indices where non zero matrix entries are present while V has the entry's value.
i, j, V = sp.find(dtm)
dtm_list = list(zip(i, j, V))
pp.pprint(dtm_list)

# %%
print(cv.vocabulary_["monsoon"])

# %%
dtm_list[0:5]

# %%
max(dtm_list, key=itemgetter(2))

# %%
# Explore the terms in the vocabulary
terms = cv.vocabulary_

# Look for a single term confuse
search_word = 'blizzard'
print("Chosen Word ({0}): Column = {1}".format(search_word, terms[search_word]))

# Find the maximum value in dtm_list in 3rd column which will be 114455
max_key = max(dtm_list, key=itemgetter(2))[1]

# Find the minimum value in dtm_list in 3rd column which will be 2336
min_key = min(dtm_list, key=itemgetter(2))[1]

# In the below two lines, terms.keys() will return all keys - i.e. the column names(words).
# For loop iterates over all this words to see get the column name which matches the column index we have in max_key and min_key
x_max = [key for key in terms.keys() if terms[key] == max_key]
x_min = [key for key in terms.keys() if terms[key] == min_key]

# the for loop above returned a list as output. So x_max is a list with a column name as same with x_min
print("Max Word ({0}): Column = {1}".format(x_max[0], max_key))
print("Min Word ({0}): Column = {1}".format(x_min[0], min_key))

# %%
# Tokenize a text document
# word_tokenize() is tokenizing the message and each word is being converted to lowercase. 
# So words has the vocabulary of message
words = [word.lower() for word in nltk.word_tokenize(message)]
top_display=25

# Count number of occurances for each token
counts = nltk.FreqDist(words)
pp.pprint(counts.most_common(top_display))

# %%
# Tokenize a text document
# word_tokenize() is tokenizing the message and each word is being converted to lowercase. 
# So words has the vocabulary of message
words = [word.lower() for word in nltk.word_tokenize(message_procc)]
top_display=25

# Count number of occurances for each token
counts = nltk.FreqDist(words)
pp.pprint(counts.most_common(top_display))

# %%
# Specify a Regular Expression to parse a text document

pattern = re.compile(r'[^\w\s]')
words = [word.lower() for word in nltk.word_tokenize(re.sub(pattern, ' ', message_procc))]

# Count token occurances
counts = nltk.FreqDist(words)
pp.pprint(counts.most_common(top_display))

# %%
num_words = len(words)
num_tokens = len(counts)
lexdiv  =  num_words / num_tokens
print("Message has %i tokens and %i words for a lexical diversity of %0.3f" % (num_tokens, num_words, lexdiv))

# %%
# Display number of unique tokens (or bins)
print('Number of unique bins(tokens) = {0}\n'.format(counts.B()))
print('Number of sample outcomes = {0}\n'.format(counts.N()))
print('Maximum occuring token = {0}\n'.format(counts.max()))

print('{0:12s}: {1}'.format('Term', 'Count'))
print(25*'-')

for token, freq in counts.most_common(top_display):
    print('{0:12s}:  {1:4.3f}'.format(token, freq))

# %%
# Hapaxes
pp.pprint(counts.hapaxes()[:10])

# %%
# Number of elements to display
top_display=10
counts.tabulate(top_display)

# %%
fig, axs = plt.subplots(figsize=(10,6))
sns.set(style="white", font_scale=1.5)
sns.despine(offset=5)#, trim=True)
counts.plot(top_display, cumulative=True)
axs.set_title('Term Count')
plt.show()

# %%
# Sample sentance to tokenize
my_text = message_procc

cv1 = CountVectorizer(lowercase=True)
cv2 = CountVectorizer(stop_words = 'english', lowercase=True)

tk_func1 = cv1.build_analyzer()
tk_func2 = cv2.build_analyzer()

pp = pprint.PrettyPrinter(indent=2, depth=1, width=80, compact=True)

print('Tokenization:')
pp.pprint(tk_func1(my_text))

print()

print('Tokenization (with Stop words):')
pp.pprint(tk_func2(my_text))

# %%
tk_func1

# %%
new_text = message_procc
stemmer = PorterStemmer()
tokens = nltk.word_tokenize(new_text)
tokens = [token for token in tokens if token not in string.punctuation]

for w in tokens:
    print(stemmer.stem(w))

# %%
english['text']0
