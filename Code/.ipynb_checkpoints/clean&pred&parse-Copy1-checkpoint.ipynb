# %%
since_date = '2021-07-13'
until_date = '2021-07-14'

# %%
import os
import pandas as pd
# import snscrape.modules.twitter as sntwitter
import numpy as np
import datetime
# from capstone_twitter_search import twittsearch

import re                                        # to handle regular expressions
# from string import punctuation                   # to extract the puntuation symbols
# import nltk
from nltk.tokenize import word_tokenize          # to divide strings into tokens
# from nltk.stem import WordNetLemmatizer          # to lemmatize the tokens
# from nltk.corpus import stopwords                # to remove the stopwords 

# import random                                    # for generating (pseudo-)random numbers
# import matplotlib.pyplot as plt                  # to plot some visualizations
# import datetime
import tensorflow as tf            
# from tensorflow import keras
# from tensorflow.keras import layers
# from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
# from tensorflow.keras.layers import Embedding
# from tensorflow.keras.callbacks import EarlyStopping
# from mordecai import Geoparser
# #from mordecai import batch_geoparse
# from flatten_json import flatten_json

# import json
# from tensorflow.keras import layers
import text_proccessing
from text_proccessing import clean_text
from text_proccessing import remove_stopwords
from text_proccessing import lemmatize_text
from text_proccessing import concatenate_text
from text_proccessing import makeglove
from text_proccessing import make_embedding_matrix

import modhelp
from modhelp import train_val_split
from modhelp import geo_df
from modhelp import suggest_nn2

# %%
code_dir = os.getcwd()

parent_dir = os.path.dirname(code_dir)
data_dir = os.path.join(parent_dir,"Data")
dsa= os.path.dirname(parent_dir)
tweet_dir = os.path.join(parent_dir,"TweetMap")
directory = os.path.join(data_dir,'splits')

# %%
train_data = pd.read_csv(os.path.join(directory, 'InformativenessTrain_Tokenized.csv'),engine='python')
train_data['text']= train_data['text'].astype(str)

# %%
start =  datetime.datetime.now() 
print('splitthis started at: {}'.format(start))
train_samples, val_samples, train_labels, val_labels = train_val_split(train_data, 0.25)
end =  datetime.datetime.now() 
print ('Text done {}'.format(end-start))
start =  datetime.datetime.now() 
print('Loading model,embedding and glove commenced at  {}'.format(start))

model = tf.keras.models.load_model(os.path.join(dsa,'model1'))
print("loading vecotor")
path_to_glove_file = os.path.join(dsa,'WordVector','glove.twitter.27B.200d.txt')

print("indexing")
embeddings_index=makeglove(path_to_glove_file)
print("matrix and vectorize")
embedding_matrix, vectorizer = make_embedding_matrix(train_samples, val_samples, embeddings_index)
end =  datetime.datetime.now() 

print("embedded in {}".format(end-start))
# Out:
# splitthis started at: 2021-07-16 09:27:30.796404
# Total size of the dataset: 117339.
# Training dataset: 88005.
# Validation dataset: 29334.
# Text done 0:00:00.023776
# Loading model,embedding and glove commenced at  2021-07-16 09:27:30.820505
# loading vecotor
# indexing
# matrix and vectorize
# Converted 32276 words (22724 misses).
# embedded in 0:01:42.936732

# %%
twts = pd.read_csv(os.path.join(tweet_dir,'tweets_df_{0}_{1}.csv'.
                              format(since_date.replace('-',''),until_date.replace('-',''))), engine = 'python')
twts['Text'] = twts['Text'].astype(str)
twts = twts[['Datetime', 'TweetId', 'Text','TweetLink','ptext','target']]

# %%
procstart =  datetime.datetime.now()
print("{}: processing ".format(procstart))
twts['ptext'] = twts['Text'].apply(lambda x: clean_text(x))
twts['ptext'] = twts['ptext'].apply(lambda x: word_tokenize(x))
twts['ptext'] = twts['ptext'].apply(lambda x : remove_stopwords(x))
twts['ptext'] = twts['ptext'].apply(lambda x : lemmatize_text(x))
twts['ptext'] = twts['ptext'].apply(lambda x : concatenate_text(x))
procend=  datetime.datetime.now() 
print("{}: processed in {}".format(procend, procend - procstart))
# Out:
# 2021-07-16 09:29:14.511848: processing
# 2021-07-16 09:31:39.905648: processed in 0:02:25.393800

# %%
predstart = datetime.datetime.now() 
print("{}: predict".format(predstart))
predictions = suggest_nn2(twts, model,vectorizer)

submission_data = {"ID": twts['TweetId'].tolist(),"tweet": twts['Text'].tolist(), "target": predictions}

submission_df = pd.DataFrame(submission_data)
result = twts.join(submission_df.target)
predend = datetime.datetime.now() 
print("predicted {}".format(predend-predstart))
# 
result_inf = result[result['target']==0]
print("working over {} informative tweets".format(len(result_inf)))
# Out:
# 2021-07-16 09:31:39.926814: predict
# predicted 0:00:51.106843
# working over 39103 informative tweets

# %%
res3 = res2[['Datetime', 'TweetId', 'Text','TweetLink','ptext','target']]

# %%
res3
# Out:
#                        Datetime              TweetId  \
# 0     2021-07-13 23:59:55+00:00  1415098697898094599
# 1     2021-07-13 23:59:55+00:00  1415098697273204737
# 3     2021-07-13 23:59:54+00:00  1415098691862544409
# 5     2021-07-13 23:59:53+00:00  1415098689589231617
# 7     2021-07-13 23:59:52+00:00  1415098683448709122
# ...                         ...                  ...
# 1459  2021-07-13 23:26:43+00:00  1415090342580342793
# 1463  2021-07-13 23:26:36+00:00  1415090313778114563
# 1464  2021-07-13 23:26:36+00:00  1415090311433396227
# 1466  2021-07-13 23:26:34+00:00  1415090304470769665
# 1469  2021-07-13 23:26:29+00:00  1415090285919473665
#
#                                                    Text  \
# 0     @PleaseBeGneiss So what you're saying is that ...
# 1     THE NATIONAL WEATHER SERVICE IN POCATELLO HAS ...
# 3     When there’s a severe thunderstorm warning I f...
# 5     @_Freeze________ @daantjiedonner @jason_carrie...
# 7     @KnowNothingTV Finalky a black man speaking th...
# ...                                                 ...
# 1459  This is such a niche complaint, but I HATE my ...
# 1463  Like the tornado ripping tbroyghtbe store whil...
# 1464  Severe Thunderstorm Warning including Mansfiel...
# 1466  Severe Thunderstorm Warning including Mansfiel...
# 1469  @AbeAnimated @Canadianguyehh At least it’s jus...
#
#                                               TweetLink  \
# 0     https://twitter.com/megansophie2020/status/141...
# 1     https://twitter.com/MichaelCoatsWX/status/1415...
# 3     https://twitter.com/mj_inglis/status/141509869...
# 5     https://twitter.com/fguerrero03/status/1415098...
# 7     https://twitter.com/KarenSnow65/status/1415098...
# ...                                                 ...
# 1459  https://twitter.com/hurricane_jane9/status/141...
# 1463  https://twitter.com/jaffajai/status/1415090313...
# 1464  https://twitter.com/NWSStateCollege/status/141...
# 1466  https://twitter.com/NWSSevereTstorm/status/141...
# 1469  https://twitter.com/DavidMe73938129/status/141...
#
#                                                   ptext  target
# 0                      youre saying need snow year long       0
# 1     national weather service pocatello issued asev...       0
# 3     ’ severe thunderstorm warning feel disappointe...       0
# 5     wrong number jack welfare state federal tax re...       0
# 7     finalky black man speaking truth slavery never...       0
# ...                                                 ...     ...
# 1459  niche complaint hate current intakeassessment ...       0
# 1463  like tornado ripping tbroyghtbe store myrtle h...       0
# 1464  severe thunderstorm warning including mansfiel...       0
# 1466  severe thunderstorm warning including mansfiel...       0
# 1469                   least ’ tropical storm hurricane       0
#
# [1000 rows x 6 columns]

# %%
print("Run geoprocessing over tweets")

geostart =  datetime.datetime.now() 
print("{}: geostart".format(geostart))
df_js = geo_df(res3)
geoend =  datetime.datetime.now()
print("{}: geoend {}".format(geoend,geoend-geostart))

df_js.to_csv(os.path.join(tweet_dir,'result_{0}_{1}.csv'.
                              format(since_date.replace('-',''),until_date.replace('-',''))))
print("fín")
# Out:
# Run geoprocessing over tweets
# 2021-07-16 09:47:17.151340: geostart
# Models path: /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/mordecai/models/
# You may be using an outdated Geonames index/Mordecai version.
# Your index is from 2018-06-05, while your Mordecai version is from 2020-07-11. Please see
# https://github.com/openeventdata/mordecai/ for instructions on updating.
#  12%|█▎        | 125/1000 [00:05<01:04, 13.60it/s]Traceback (most recent call last):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/mordecai/geoparse.py", line 726, in infer_country
#     prediction = self.country_model.predict(i['matrix']).transpose()[0]
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1629, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 862, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2941, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3357, in _maybe_define_function
#     return self._define_function_with_shape_relaxation(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _define_function_with_shape_relaxation
#     graph_function = self._create_graph_function(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:255 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (None, 0)
#
#  15%|█▍        | 148/1000 [00:05<00:25, 32.99it/s]
# None
#  26%|██▌       | 255/1000 [00:09<00:25, 28.69it/s]Traceback (most recent call last):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/mordecai/geoparse.py", line 726, in infer_country
#     prediction = self.country_model.predict(i['matrix']).transpose()[0]
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1629, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 862, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2941, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3357, in _maybe_define_function
#     return self._define_function_with_shape_relaxation(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _define_function_with_shape_relaxation
#     graph_function = self._create_graph_function(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:255 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (None, 0)
#
#  26%|██▋       | 263/1000 [00:09<00:21, 34.17it/s]
# None
#  29%|██▉       | 293/1000 [00:10<00:16, 42.55it/s]Traceback (most recent call last):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/mordecai/geoparse.py", line 726, in infer_country
#     prediction = self.country_model.predict(i['matrix']).transpose()[0]
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1629, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 862, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2941, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3357, in _maybe_define_function
#     return self._define_function_with_shape_relaxation(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _define_function_with_shape_relaxation
#     graph_function = self._create_graph_function(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:255 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (None, 0)
#
#  30%|██▉       | 298/1000 [00:11<00:43, 16.32it/s]
# None
#  49%|████▉     | 492/1000 [00:17<00:16, 31.70it/s]Traceback (most recent call last):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/mordecai/geoparse.py", line 726, in infer_country
#     prediction = self.country_model.predict(i['matrix']).transpose()[0]
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1629, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 862, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2941, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3357, in _maybe_define_function
#     return self._define_function_with_shape_relaxation(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _define_function_with_shape_relaxation
#     graph_function = self._create_graph_function(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:255 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (None, 0)
#
#  51%|█████     | 509/1000 [00:18<00:09, 49.83it/s]
# None
#  58%|█████▊    | 578/1000 [00:20<00:24, 16.94it/s]Traceback (most recent call last):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/mordecai/geoparse.py", line 726, in infer_country
#     prediction = self.country_model.predict(i['matrix']).transpose()[0]
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1629, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 862, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2941, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3357, in _maybe_define_function
#     return self._define_function_with_shape_relaxation(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _define_function_with_shape_relaxation
#     graph_function = self._create_graph_function(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:255 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (None, 0)
#
#  59%|█████▊    | 586/1000 [00:20<00:19, 21.12it/s]
# None
#  93%|█████████▎| 929/1000 [00:31<00:02, 33.28it/s]Traceback (most recent call last):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/mordecai/geoparse.py", line 726, in infer_country
#     prediction = self.country_model.predict(i['matrix']).transpose()[0]
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1629, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 862, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2941, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3357, in _maybe_define_function
#     return self._define_function_with_shape_relaxation(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _define_function_with_shape_relaxation
#     graph_function = self._create_graph_function(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:255 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (None, 0)
#
#  94%|█████████▍| 938/1000 [00:32<00:01, 35.30it/s]Traceback (most recent call last):
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/mordecai/geoparse.py", line 726, in infer_country
#     prediction = self.country_model.predict(i['matrix']).transpose()[0]
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1629, in predict
#     tmp_batch_outputs = self.predict_function(iterator)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 862, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2941, in __call__
#     filtered_flat_args) = self._maybe_define_function(args, kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3357, in _maybe_define_function
#     return self._define_function_with_shape_relaxation(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _define_function_with_shape_relaxation
#     graph_function = self._create_graph_function(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 634, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 977, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /Volumes/Elements/DataScience/anaconda3/envs/machinelearning/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:255 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (None, 0)
#
#  94%|█████████▍| 942/1000 [00:32<00:01, 33.78it/s]
# None
# None
# 100%|██████████| 1000/1000 [00:36<00:00, 27.56it/s]
# /Volumes/Elements/DataScience/dsa/capstone/Code/modhelp.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['geos'] = geo.batch_geoparse(df['Text'])
# 2021-07-16 09:48:17.783584: geoend 0:01:00.632244
# fín

# %%
res3.head()
# Out:
#                     Datetime              TweetId  \
# 0  2021-07-13 23:59:55+00:00  1415098697898094599
# 1  2021-07-13 23:59:55+00:00  1415098697273204737
# 3  2021-07-13 23:59:54+00:00  1415098691862544409
# 5  2021-07-13 23:59:53+00:00  1415098689589231617
# 7  2021-07-13 23:59:52+00:00  1415098683448709122
#
#                                                 Text  \
# 0  @PleaseBeGneiss So what you're saying is that ...
# 1  THE NATIONAL WEATHER SERVICE IN POCATELLO HAS ...
# 3  When there’s a severe thunderstorm warning I f...
# 5  @_Freeze________ @daantjiedonner @jason_carrie...
# 7  @KnowNothingTV Finalky a black man speaking th...
#
#                                            TweetLink  \
# 0  https://twitter.com/megansophie2020/status/141...
# 1  https://twitter.com/MichaelCoatsWX/status/1415...
# 3  https://twitter.com/mj_inglis/status/141509869...
# 5  https://twitter.com/fguerrero03/status/1415098...
# 7  https://twitter.com/KarenSnow65/status/1415098...
#
#                                                ptext  target  \
# 0                   youre saying need snow year long       0
# 1  national weather service pocatello issued asev...       0
# 3  ’ severe thunderstorm warning feel disappointe...       0
# 5  wrong number jack welfare state federal tax re...       0
# 7  finalky black man speaking truth slavery never...       0
#
#                                                 geos
# 0                                                 []
# 1  [{'word': 'MARYSVILLE', 'spans': [{'start': 15...
# 3                                                 []
# 5                                                 []
# 7                                                 []

# %%
df_js.head()
# Out:
#                      Datetime              TweetId  \
# 1   2021-07-13 23:59:55+00:00  1415098697273204737
# 16  2021-07-13 23:59:46+00:00  1415098661084663812
# 16  2021-07-13 23:59:46+00:00  1415098661084663812
# 16  2021-07-13 23:59:46+00:00  1415098661084663812
# 20  2021-07-13 23:59:41+00:00  1415098639052124161
#
#                                                  Text  \
# 1   THE NATIONAL WEATHER SERVICE IN POCATELLO HAS ...
# 16  USGS reports a M1.1 earthquake, 11 km WNW of W...
# 16  USGS reports a M1.1 earthquake, 11 km WNW of W...
# 16  USGS reports a M1.1 earthquake, 11 km WNW of W...
# 20  @manisweetener seeing a further explanation ab...
#
#                                             TweetLink  \
# 1   https://twitter.com/MichaelCoatsWX/status/1415...
# 16  https://twitter.com/everyEarthquake/status/141...
# 16  https://twitter.com/everyEarthquake/status/141...
# 16  https://twitter.com/everyEarthquake/status/141...
# 20  https://twitter.com/blu_x0x/status/14150986390...
#
#                                                 ptext  target        word  \
# 1   national weather service pocatello issued asev...       0  MARYSVILLE
# 16  usgs report earthquake km wnw willow alaska ut...       0        M1.1
# 16  usgs report earthquake km wnw willow alaska ut...       0      Willow
# 16  usgs report earthquake km wnw willow alaska ut...       0      Alaska
# 20  seeing explanation hip hop hairstyle koreathis...       0       korea
#
#                            spans country_predicted  country_conf   0  \
# 1   [{'start': 157, 'end': 167}]               USA      0.957188 NaN
# 16    [{'start': 15, 'end': 19}]               GBR      0.927073 NaN
# 16    [{'start': 45, 'end': 51}]               USA      0.951695 NaN
# 16    [{'start': 53, 'end': 59}]               USA      0.963498 NaN
# 20    [{'start': 84, 'end': 89}]               KOR      0.879922 NaN
#
#         admin1 country_code3 feature_class feature_code geonameid       lat  \
# 1   Washington           USA             P          PPL   5802570  48.05176
# 16     England           GBR             S          HTL  10281411  52.20566
# 16      Alaska           USA             P          PPL   5878102  61.74722
# 16      Alaska           USA             A         ADM1   5879092  64.00028
# 20          NA           KOR             A         PCLI   1835841  36.50000
#
#           lon                                        place_name
# 1  -122.17708                                        Marysville
# 16    0.12415  Holiday Inn Express Cambridge Duxford M11 Jct 10
# 16 -150.03750                                            Willow
# 16 -150.00028                                            Alaska
# 20  127.75000                                 Republic of Korea
