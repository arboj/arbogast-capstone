# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Jul 15 08:29:53 2021

@author: Arbo
"""
import os
import pandas as pd
code_dir = os.getcwd()
parent_dir = os.path.dirname(code_dir)
data_dir = os.path.join(parent_dir,"Data")
tweet_dir = os.path.join(parent_dir,"GeoTweets")
# def append_df(tweet_dir):
    
#     tweets_df = pd.DataFrame(
#                          columns=['Datetime', 'TweetId', 'Text',])
    
#     for table in os.listdir(tweet_dir):
#         if table.startswith("tweets"):
#             tempdf = pd.read_csv(os.path.join(tweet_dir,table), engine = 'python', )
            
#             tweets_df = tweets_df.append(tempdf)      
#     tweets_df['Text'] = tweets_df['Text'].astype(str)        
#     return tweets_df

# %%
wxevents= ["tornado","blizzard","snow", "ice storm","sleet","thunderstorm","hail","freeze","frost","extreme cold","lightning",    "winds"       
"gale","storm"]
movement=["landslide" , "tsunami" , "tidal wave" , "earthquake" , "eruption" , 
          "volcano" , "lava" , "lahar" , "avalanche" , "mudslide" , "sinkhole"]
troplist=["typhoon" ,"cyclone","hurricane", "tropical storm","storm surge"]
flist= ["fire", "forest fire", "wildfire", "bushfire", "extreme heat", "record heat", "heatwave" , "heat wave" ]
floods = ["flood","flooded","flooding"]

# %%
df = pd.read_csv(os.path.join(tweet_dir,'geod_20210629_20210630.csv'), engine = 'python', )

# %%
df.head()
# Out:
#                     Datetime              TweetId  \
# 0  2021-06-29 23:59:58+00:00  1410025281474240515
# 1  2021-06-29 23:59:58+00:00  1410025281474240515
# 2  2021-06-29 23:59:58+00:00  1410025278357770243
# 3  2021-06-29 23:59:58+00:00  1410025278357770243
# 4  2021-06-29 23:59:50+00:00  1410025246971858946
#
#                                                 Text  \
# 0  T-Storm WARNING for SE Albany.... Southern Ren...
# 1  T-Storm WARNING for SE Albany.... Southern Ren...
# 2  One, two, three ... the town of Lytton in Brit...
# 3  One, two, three ... the town of Lytton in Brit...
# 4  JUST IN 🚨 145 sudden deaths reported in Metro ...
#
#                                            TweetLink  \
# 0  https://twitter.com/Tim_Drawbridge/status/1410...
# 1  https://twitter.com/Tim_Drawbridge/status/1410...
# 2  https://twitter.com/KHayhoe/status/14100252783...
# 3  https://twitter.com/KHayhoe/status/14100252783...
# 4  https://twitter.com/TheInsiderPaper/status/141...
#
#                                                ptext  target  \
# 0  tstorm warning se albany southern rensselaer n...       0
# 1  tstorm warning se albany southern rensselaer n...       0
# 2  one two three town lytton british columbia bre...       0
# 3  one two three town lytton british columbia bre...       0
# 4  🚨 sudden death reported metro vancouver amid r...       0
#
#                 word                         spans country_predicted  \
# 0  Northern Columbia    [{'start': 75, 'end': 92}]               USA
# 1          Schoharie  [{'start': 264, 'end': 273}]               USA
# 2             Lytton    [{'start': 32, 'end': 38}]               USA
# 3   British Columbia    [{'start': 42, 'end': 58}]               CAN
# 4    Metro Vancouver    [{'start': 40, 'end': 55}]               CAN
#
#    country_conf   0            admin1 country_code3 feature_class  \
# 0      0.963741 NaN          New York           USA             S
# 1      0.904877 NaN          New York           USA             A
# 2      0.813797 NaN              Iowa           USA             A
# 3      0.895296 NaN  British Columbia           CAN             A
# 4      0.895296 NaN  British Columbia           CAN             A
#
#   feature_code  geonameid       lat        lon  \
# 0           CH    7225118  42.36139  -73.60278
# 1         ADM2    5136495  42.58822  -74.44212
# 2         ADMD    7317192  42.42330  -94.86050
# 3         ADM1    5909050  53.99983 -125.00320
# 4         ADM2    5965814  49.33296 -123.00264
#
#                              place_name
# 0  Northern Columbia Evangelical Church
# 1                      Schoharie County
# 2                        City of Lytton
# 3                      British Columbia
# 4     Metro Vancouver Regional District

# %%
df['flood']=df.ptext.str.contains('|'.join(wxevents))
#Out[78]: [True, True, False]

# %%
df[df['flood']==True]
# Out:
#                         Datetime              TweetId  \
# 0      2021-06-29 23:59:58+00:00  1410025281474240515
# 1      2021-06-29 23:59:58+00:00  1410025281474240515
# 8      2021-06-29 23:59:41+00:00  1410025209365733376
# 9      2021-06-29 23:59:06+00:00  1410025060446965771
# 13     2021-06-29 23:57:56+00:00  1410024769387384833
# ...                          ...                  ...
# 11563  2021-06-29 00:01:37+00:00  1409663307691134978
# 11564  2021-06-29 00:01:37+00:00  1409663307691134978
# 11565  2021-06-29 00:01:37+00:00  1409663307691134978
# 11573  2021-06-29 00:01:14+00:00  1409663209359822848
# 11578  2021-06-29 00:00:29+00:00  1409663020758835204
#
#                                                     Text  \
# 0      T-Storm WARNING for SE Albany.... Southern Ren...
# 1      T-Storm WARNING for SE Albany.... Southern Ren...
# 8      @AndrewBVCU @MajinBaydat @ViolenceOnTV @TheSag...
# 9      Is it coming home? Kate and Prince William hai...
# 13     @ThisIsREngland We had a weak tornado touch do...
# ...                                                  ...
# 11563  Looking west from our Tall Towercam we can see...
# 11564  Looking west from our Tall Towercam we can see...
# 11565  Looking west from our Tall Towercam we can see...
# 11573  @GovPritzker @LtGovStratton @IllinoisDCEO To b...
# 11578  First time visiting the Tornado damage in Nape...
#
#                                                TweetLink  \
# 0      https://twitter.com/Tim_Drawbridge/status/1410...
# 1      https://twitter.com/Tim_Drawbridge/status/1410...
# 8      https://twitter.com/TerjeCS/status/14100252093...
# 9      https://twitter.com/theroyaleditor/status/1410...
# 13     https://twitter.com/InAbsentiaWA/status/141002...
# ...                                                  ...
# 11563  https://twitter.com/mazewx66/status/1409663307...
# 11564  https://twitter.com/mazewx66/status/1409663307...
# 11565  https://twitter.com/mazewx66/status/1409663307...
# 11573  https://twitter.com/PatrickFitzmau2/status/140...
# 11578  https://twitter.com/MikeS_WX/status/1409663020...
#
#                                                    ptext  target  \
# 0      tstorm warning se albany southern rensselaer n...       0
# 1      tstorm warning se albany southern rensselaer n...       0
# 8      isnt dipshit lmao barely snow year norway know...       0
# 9      coming home kate prince william hail england i...       0
# 13     weak tornado touch nh week moved new house luc...       0
# ...                                                  ...     ...
# 11563  looking west tall towercam see thunderstorm mo...       0
# 11564  looking west tall towercam see thunderstorm mo...       0
# 11565  looking west tall towercam see thunderstorm mo...       0
# 11573  bad ’ time go tornado ravage naperville amp wo...       0
# 11578  first time visiting tornado damage naperville…...       0
#
#                     word                         spans country_predicted  \
# 0      Northern Columbia    [{'start': 75, 'end': 92}]               USA
# 1              Schoharie  [{'start': 264, 'end': 273}]               USA
# 8                 norway  [{'start': 134, 'end': 140}]               USA
# 9                Germany  [{'start': 124, 'end': 131}]               DEU
# 13                    NH    [{'start': 52, 'end': 54}]               LUX
# ...                  ...                           ...               ...
# 11563            Chatham   [{'start': 99, 'end': 106}]               USA
# 11564          Pittsboro  [{'start': 182, 'end': 191}]               USA
# 11565         Siler City  [{'start': 196, 'end': 206}]               USA
# 11573          Woodridge  [{'start': 112, 'end': 121}]               USA
# 11578         Naperville    [{'start': 42, 'end': 52}]               USA
#
#        country_conf   0          admin1 country_code3 feature_class  \
# 0          0.963741 NaN        New York           USA             S
# 1          0.904877 NaN        New York           USA             A
# 8          0.879922 NaN        Michigan           USA             P
# 9          0.953179 NaN             NaN           DEU             A
# 13         0.904877 NaN             NaN           LUX             S
# ...             ...  ..             ...           ...           ...
# 11563      0.963741 NaN         Georgia           USA             A
# 11564      0.904877 NaN  North Carolina           USA             P
# 11565      0.963741 NaN  North Carolina           USA             P
# 11573      0.957188 NaN        Illinois           USA             P
# 11578      0.963741 NaN        Illinois           USA             L
#
#       feature_code  geonameid       lat       lon  \
# 0               CH    7225118  42.36139 -73.60278
# 1             ADM2    5136495  42.58822 -74.44212
# 8              PPL    5004016  45.78690 -87.90374
# 9             PCLI    2921044  51.50000  10.50000
# 13             HTL    6469061  49.63900   6.21800
# ...            ...        ...       ...       ...
# 11563         ADM2    4187390  31.97402 -81.09243
# 11564        PPLA2    4485655  35.72015 -79.17724
# 11565          PPL    4491651  35.72347 -79.46224
# 11573          PPL    4917089  41.74697 -88.05034
# 11578         RGNE    6955104  41.70778 -87.89062
#
#                                  place_name  flood
# 0      Northern Columbia Evangelical Church   True
# 1                          Schoharie County   True
# 8                                    Norway   True
# 9               Federal Republic of Germany   True
# 13                            NH Luxembourg   True
# ...                                     ...    ...
# 11563                        Chatham County   True
# 11564                             Pittsboro   True
# 11565                            Siler City   True
# 11573                             Woodridge   True
# 11578             Chicago-Naperville-Joliet   True
#
# [3381 rows x 20 columns]

# %%
df.head()
# Out:
#                     Datetime              TweetId  \
# 0  2021-06-29 23:59:58+00:00  1410025281474240515
# 1  2021-06-29 23:59:58+00:00  1410025281474240515
# 2  2021-06-29 23:59:58+00:00  1410025278357770243
# 3  2021-06-29 23:59:58+00:00  1410025278357770243
# 4  2021-06-29 23:59:50+00:00  1410025246971858946
#
#                                                 Text  \
# 0  T-Storm WARNING for SE Albany.... Southern Ren...
# 1  T-Storm WARNING for SE Albany.... Southern Ren...
# 2  One, two, three ... the town of Lytton in Brit...
# 3  One, two, three ... the town of Lytton in Brit...
# 4  JUST IN 🚨 145 sudden deaths reported in Metro ...
#
#                                            TweetLink  \
# 0  https://twitter.com/Tim_Drawbridge/status/1410...
# 1  https://twitter.com/Tim_Drawbridge/status/1410...
# 2  https://twitter.com/KHayhoe/status/14100252783...
# 3  https://twitter.com/KHayhoe/status/14100252783...
# 4  https://twitter.com/TheInsiderPaper/status/141...
#
#                                                ptext  target  \
# 0  tstorm warning se albany southern rensselaer n...       0
# 1  tstorm warning se albany southern rensselaer n...       0
# 2  one two three town lytton british columbia bre...       0
# 3  one two three town lytton british columbia bre...       0
# 4  🚨 sudden death reported metro vancouver amid r...       0
#
#                 word                         spans country_predicted  \
# 0  Northern Columbia    [{'start': 75, 'end': 92}]               USA
# 1          Schoharie  [{'start': 264, 'end': 273}]               USA
# 2             Lytton    [{'start': 32, 'end': 38}]               USA
# 3   British Columbia    [{'start': 42, 'end': 58}]               CAN
# 4    Metro Vancouver    [{'start': 40, 'end': 55}]               CAN
#
#    country_conf   0            admin1 country_code3 feature_class  \
# 0      0.963741 NaN          New York           USA             S
# 1      0.904877 NaN          New York           USA             A
# 2      0.813797 NaN              Iowa           USA             A
# 3      0.895296 NaN  British Columbia           CAN             A
# 4      0.895296 NaN  British Columbia           CAN             A
#
#   feature_code  geonameid       lat        lon  \
# 0           CH    7225118  42.36139  -73.60278
# 1         ADM2    5136495  42.58822  -74.44212
# 2         ADMD    7317192  42.42330  -94.86050
# 3         ADM1    5909050  53.99983 -125.00320
# 4         ADM2    5965814  49.33296 -123.00264
#
#                              place_name  flood
# 0  Northern Columbia Evangelical Church  False
# 1                      Schoharie County  False
# 2                        City of Lytton  False
# 3                      British Columbia  False
# 4     Metro Vancouver Regional District  False

# %%
juneDFs=[]
for table in os.listdir(os.path.join(tweet_dir)):
    if table.startswith("geo"):
        tempdf = pd.read_csv(os.path.join(tweet_dir,table), engine = 'python', )
        juneDFs.append(tempdf)

# %%
for x in range(len(juneDFs)):
    juneDFs[x] = juneDFs[x].drop(columns = ['TweetLink', '0'])

    print("Column Names for June Data{}: {} ".format(x,juneDFs[x].columns))
# Out:
# Column Names for June Data0: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data1: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data2: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data3: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data4: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data5: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data6: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data7: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data8: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data9: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data10: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data11: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data12: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data13: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data14: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data15: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data16: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data17: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data18: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data19: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data20: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data21: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data22: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data23: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data24: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data25: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data26: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data27: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data28: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for June Data29: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')

# %%
JuneAll = pd.concat(juneDFs)
JuneAll= JuneAll.drop([4920,4921])

# %%
JuneAll.to_csv(os.path.join(tweet_dir,"JuneTweets.csv"), index = False)

# %%
# Out:
#                                                Datetime  \
# 4920                          2021-06-02 15:30:09+00:00
# 4921  Saskatchewan Rattlers / Adirondack Thunder htt...
#
#                                                 TweetId  \
# 4920                                1400112509693181953
# 4921  https://twitter.com/HouseDividedBot/status/140...
#
#                                                    Text         ptext  \
# 4920                                    A HOUSE DIVIDED          None
# 4921  house divided saskatchewan rattler adirondack ...  Saskatchewan
#
#                           target  word               spans country_predicted  \
# 4920                        None  None                None              None
# 4921  [{'start': 16, 'end': 28}]   CAN  0.9048774242401123               NaN
#
#       country_conf admin1 country_code3 feature_class feature_code  geonameid  \
# 4920          None   None          None          None         None        NaN
# 4921  Saskatchewan      A          ADM1       6141242      54.0001 -106.00099
#
#                lat  lon place_name
# 4920          None  NaN       None
# 4921  Saskatchewan  NaN       None

# %%
julyDFs=[]
for table in os.listdir(os.path.join(tweet_dir)):
    if table.startswith("geod"):
        tempdf = pd.read_csv(os.path.join(tweet_dir,table), engine = 'python', )
        julyDFs.append(tempdf)

# %%
for x in range(len(julyDFs)):
    try:
        julyDFs[x] = julyDFs[x].drop(columns = ['TweetLink', '0'])
    except:
        julyDFs[x] = julyDFs[x].drop(columns = ['0'])
    print("Column Names for July Data{}: {} ".format(x,julyDFs[x].columns))
# Out:
# Column Names for July Data0: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data1: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data2: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data3: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data4: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data5: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data6: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data7: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data8: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data9: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data10: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data11: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data12: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data13: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data14: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data15: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data16: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')
# Column Names for July Data17: Index(['Datetime', 'TweetId', 'Text', 'ptext', 'target', 'word', 'spans',
#        'country_predicted', 'country_conf', 'admin1', 'country_code3',
#        'feature_class', 'feature_code', 'geonameid', 'lat', 'lon',
#        'place_name'],
#       dtype='object')

# %%
JulyAll = pd.concat(julyDFs)

# %%
JulyAll=JulyAll.sort_values(by=['Datetime']).reset_index(drop=True)

# %%
JulyAll.tail()
# Out:
#                          Datetime              TweetId  \
# 214744  2021-07-31 23:59:50+00:00  1421621657580425217
# 214745  2021-07-31 23:59:50+00:00  1421621657580425217
# 214746  2021-07-31 23:59:50+00:00  1421621657580425217
# 214747  2021-07-31 23:59:50+00:00  1421621657580425217
# 214748  2021-07-31 23:59:58+00:00  1421621692116307970
#
#                                                      Text  \
# 214744  @RickPetree Devastating flood happening in Ger...
# 214745  @RickPetree Devastating flood happening in Ger...
# 214746  @RickPetree Devastating flood happening in Ger...
# 214747  @RickPetree Devastating flood happening in Ger...
# 214748  Running updates on the flash flooding in Bould...
#
#                                                     ptext  target     word  \
# 214744  devastating flood happening germany belgium fr...       0   France
# 214745  devastating flood happening germany belgium fr...       0  Germany
# 214746  devastating flood happening germany belgium fr...       0    China
# 214747  devastating flood happening germany belgium fr...       0   Turkey
# 214748     running update flash flooding boulder colorado       0  Boulder
#
#                              spans country_predicted  country_conf  \
# 214744  [{'start': 61, 'end': 67}]               FRA      0.945330
# 214745  [{'start': 43, 'end': 50}]               DEU      0.954475
# 214746  [{'start': 77, 'end': 82}]               CHN      0.609523
# 214747  [{'start': 69, 'end': 75}]               TUR      0.945330
# 214748  [{'start': 41, 'end': 48}]               USA      0.963498
#
#                admin1 country_code3 feature_class feature_code  geonameid  \
# 214744  Île-de-France           FRA             P          PPL    2971874
# 214745            NaN           DEU             A         PCLI    2921044
# 214746            NaN           CHN             A         PCLI    1814991
# 214747            NaN           TUR             A         PCLI     298795
# 214748       Colorado           USA             P        PPLA2    5574991
#
#              lat        lon                   place_name
# 214744  48.94956    2.56840           Tremblay-en-France
# 214745  51.50000   10.50000  Federal Republic of Germany
# 214746  35.00000  105.00000   People’s Republic of China
# 214747  39.00000   35.00000           Republic of Turkey
# 214748  40.01499 -105.27055                      Boulder

# %%
JulyAll.to_csv(os.path.join(tweet_dir,"JulyTweets.csv"), index = False)

# %%
julytest = pd.read_csv(os.path.join(tweet_dir,"JulyTweets.csv"))

# %%
julytest.tail()
# Out:
#                          Datetime              TweetId  \
# 211124  2021-07-17 23:58:47+00:00  1416547965141913608
# 211125  2021-07-17 23:58:48+00:00  1416547967394193411
# 211126  2021-07-17 23:58:48+00:00  1416547967394193411
# 211127  2021-07-17 23:58:50+00:00  1416547976789381121
# 211128  2021-07-17 23:59:43+00:00  1416548199876202502
#
#                                                      Text  \
# 211124  Very serious flash flooding in eastern Connect...
# 211125  Flash Flood Warning continues for Providence R...
# 211126  Flash Flood Warning continues for Providence R...
# 211127  Flash Flood Warning continues for Putnam CT, S...
# 211128  Three Texas Democrats \n"If the 30% don't get ...
#
#                                                     ptext  target  \
# 211124  serious flash flooding eastern connecticut hig...     0.0
# 211125  flash flood warning continues providence ri pa...     0.0
# 211126  flash flood warning continues providence ri pa...     0.0
# 211127  flash flood warning continues putnam ct south ...     0.0
# 211128  three texas democrat dont get vaccinated democ...     0.0
#
#                    word                       spans country_predicted  \
# 211124      Connecticut  [{'start': 39, 'end': 50}]               USA
# 211125     Pawtucket RI  [{'start': 49, 'end': 61}]               USA
# 211126    Providence RI  [{'start': 34, 'end': 47}]               USA
# 211127  South Woodstock  [{'start': 45, 'end': 60}]               USA
# 211128            Texas   [{'start': 6, 'end': 11}]               USA
#
#         country_conf         admin1 country_code3 feature_class feature_code  \
# 211124      0.963498    Connecticut           USA             A         ADM1
# 211125      0.963741   Rhode Island           USA             P          PPL
# 211126      0.963741  Massachusetts           USA             S          HTL
# 211127      0.963741    Connecticut           USA             P          PPL
# 211128      0.963498          Texas           USA             A         ADM1
#
#         geonameid       lat       lon                            place_name
# 211124    4831725  41.66704 -72.66648                           Connecticut
# 211125    5223869  41.87871 -71.38256                             Pawtucket
# 211126   10247818  41.95616 -71.34370  Super 8 N Attleboro Ma Providence Ri
# 211127    4843359  41.93899 -71.95952                       South Woodstock
# 211128    4736286  31.25044 -99.25061                                 Texas

# %%
#julytest2 =  pd.read_csv(os.path.join(tweet_dir,"JuneJulyTweets.csv"))
len(JulyAll)
# Out:
# 214749

# %%
JulyAll.head()
# Out:
#                     Datetime              TweetId  \
# 0  2021-07-14 00:00:00+00:00  1415098719075110912
# 1  2021-07-14 00:00:00+00:00  1415098717867282435
# 2  2021-07-14 00:00:13+00:00  1415098772128997381
# 3  2021-07-14 00:00:18+00:00  1415098793599635462
# 4  2021-07-14 00:01:04+00:00  1415098987154182150
#
#                                                 Text  \
# 0  A Long Island homeowner made a shocking discov...
# 1  A SEVERE THUNDERSTORM WARNING has been issued ...
# 2  Most of central and northern Saskatchewan is u...
# 3  Very sad update - The four people killed in th...
# 4  @FierceAndLittle I live in Marshfield and it’s...
#
#                                                ptext  target          word  \
# 0  long island homeowner made shocking discovery ...       0   Long Island
# 1  severe thunderstorm warning issued mifflin cou...       0       Mifflin
# 2  central northern saskatchewan air quality stat...       0  Saskatchewan
# 3  sad update four people killed new kent county ...       0      New Kent
# 4  live marshfield ’ esplanade whole place flood ...       0    Marshfield
#
#                         spans country_predicted  country_conf        admin1  \
# 0   [{'start': 2, 'end': 13}]               BHS      0.879922   Long Island
# 1  [{'start': 50, 'end': 57}]               USA      0.963741  Pennsylvania
# 2  [{'start': 29, 'end': 41}]               CAN      0.904877  Saskatchewan
# 3  [{'start': 48, 'end': 56}]               USA      0.963741      Virginia
# 4  [{'start': 27, 'end': 37}]               USA      0.957188     Wisconsin
#
#   country_code3 feature_class feature_code  geonameid       lat        lon  \
# 0           BHS             A         ADM1    3572005  23.21667  -75.11167
# 1           USA             A         ADM2    5201068  40.61041  -77.61704
# 2           CAN             A         ADM1    6141242  54.00010 -106.00099
# 3           USA             A         ADM2    4775834  37.50514  -76.99713
# 4           USA             P          PPL    5261969  44.66885  -90.17180
#
#         place_name
# 0      Long Island
# 1   Mifflin County
# 2     Saskatchewan
# 3  New Kent County
# 4       Marshfield

# %%
JulyAll= JulyAll.drop_duplicates()

# %%
len(JulyAll)
# Out:
# 214749

# %%
arch = pd.read_csv(os.path.join(tweet_dir,"JuneJulyTweets.csv"))

# %%
arch.head()
# Out:
#                     Datetime              TweetId  \
# 0  2021-06-01 23:59:38+00:00  1399878337653207042
# 1  2021-06-01 23:58:38+00:00  1399878086414548997
# 2  2021-06-01 23:58:36+00:00  1399878076486631427
# 3  2021-06-01 23:57:39+00:00  1399877837360975872
# 4  2021-06-01 23:57:23+00:00  1399877771103457280
#
#                                                 Text  \
# 0  @GatorGately @ThatEricAlper @CountingCrows @Cl...
# 1  THIS JUST IN: I spoke to the Canyon Lake Fire ...
# 2  New Tower for iRacing!\nMight test it out toni...
# 3  Carolina is making it tough for the Lightning ...
# 4  Something is burning over there Quarry area No...
#
#                                                ptext  target  \
# 0  ’ check mate cheer eddie vedder big fan good c...     0.0
# 1  spoke canyon lake fire chief said located drow...     0.0
# 2  new tower iracingmight test tonight live nasca...     0.0
# 3  carolina making tough lightning transition neu...     0.0
# 4  something burning quarry area north sanantonio...     0.0
#
#                     word                         spans country_predicted  \
# 0                  Fire🔥  [{'start': 161, 'end': 166}]               USA
# 1            Canyon Lake    [{'start': 29, 'end': 40}]               USA
# 2              New Tower      [{'start': 0, 'end': 9}]               MLT
# 3               Carolina      [{'start': 0, 'end': 8}]               BRA
# 4  Metropolitan hospital  [{'start': 126, 'end': 147}]               USA
#
#    country_conf        admin1 country_code3 feature_class feature_code  \
# 0      0.635326  Rhode Island           USA             S         BLDG
# 1      0.957188         Texas           USA             P          PPL
# 2      0.904877    Tas-Sliema           MLT             S          HTL
# 3      0.879922      Maranhão           BRA             A         ADM2
# 4      0.963741      Michigan           USA             S          HSP
#
#     geonameid       lat       lon  \
# 0   7211630.0  41.87928 -71.38213
# 1   4678901.0  29.87522 -98.26251
# 2  10131832.0  35.91250  14.50194
# 3   6319678.0  -7.50794 -47.14907
# 4   7254706.0  42.93503 -85.62113
#
#                                           place_name
# 0             Pawtucket Fire Department Fire Station
# 1                                        Canyon Lake
# 2                                   New Tower Palace
# 3                                           Carolina
# 4  Metropolitan Hospital (Fink Robert Retirement ...

# %%
merge = pd.concat([arch,JulyAll])

# %%
len(merge)
# Out:
# 819185

# %%
merge= merge.drop_duplicates()

# %%
len(merge)
# Out:
# 612770

# %%
merge.head()
# Out:
#                     Datetime              TweetId  \
# 0  2021-06-01 23:59:38+00:00  1399878337653207042
# 1  2021-06-01 23:58:38+00:00  1399878086414548997
# 2  2021-06-01 23:58:36+00:00  1399878076486631427
# 3  2021-06-01 23:57:39+00:00  1399877837360975872
# 4  2021-06-01 23:57:23+00:00  1399877771103457280
#
#                                                 Text  \
# 0  @GatorGately @ThatEricAlper @CountingCrows @Cl...
# 1  THIS JUST IN: I spoke to the Canyon Lake Fire ...
# 2  New Tower for iRacing!\nMight test it out toni...
# 3  Carolina is making it tough for the Lightning ...
# 4  Something is burning over there Quarry area No...
#
#                                                ptext  target  \
# 0  ’ check mate cheer eddie vedder big fan good c...     0.0
# 1  spoke canyon lake fire chief said located drow...     0.0
# 2  new tower iracingmight test tonight live nasca...     0.0
# 3  carolina making tough lightning transition neu...     0.0
# 4  something burning quarry area north sanantonio...     0.0
#
#                     word                         spans country_predicted  \
# 0                  Fire🔥  [{'start': 161, 'end': 166}]               USA
# 1            Canyon Lake    [{'start': 29, 'end': 40}]               USA
# 2              New Tower      [{'start': 0, 'end': 9}]               MLT
# 3               Carolina      [{'start': 0, 'end': 8}]               BRA
# 4  Metropolitan hospital  [{'start': 126, 'end': 147}]               USA
#
#    country_conf        admin1 country_code3 feature_class feature_code  \
# 0      0.635326  Rhode Island           USA             S         BLDG
# 1      0.957188         Texas           USA             P          PPL
# 2      0.904877    Tas-Sliema           MLT             S          HTL
# 3      0.879922      Maranhão           BRA             A         ADM2
# 4      0.963741      Michigan           USA             S          HSP
#
#     geonameid       lat       lon  \
# 0   7211630.0  41.87928 -71.38213
# 1   4678901.0  29.87522 -98.26251
# 2  10131832.0  35.91250  14.50194
# 3   6319678.0  -7.50794 -47.14907
# 4   7254706.0  42.93503 -85.62113
#
#                                           place_name
# 0             Pawtucket Fire Department Fire Station
# 1                                        Canyon Lake
# 2                                   New Tower Palace
# 3                                           Carolina
# 4  Metropolitan Hospital (Fink Robert Retirement ...

# %%
merge.to_csv(os.path.join(tweet_dir,"JuneJulyTweets.csv"), index = False)

# %%
locations = merge[['country_code3','admin1','place_name', 'geonameid']]

# %%
admin_ones = locations.drop_duplicates(['country_code3','admin1'])
admin_ones = admin_ones[['country_code3','admin1']]

# %%
admin_ones = admin_ones.sort_values(by=['country_code3', 'admin1'])

# %%
admin_ones.to_csv(os.path.join(tweet_dir,"Admin_ones.csv"), index = False)

# %%
geonames = locations.drop_duplicates('geonameid')
geonames = geonames[['geonameid','place_name','country_code3','admin1']]

# %%
geonames = geonames.sort_values(by=['country_code3','admin1','place_name'])

# %%
geonames
# Out:
#          geonameid                                         place_name  \
# 562301  10340008.0         Aruba Marriott Resort and Stellaris Casino
# 410870   9957912.0  Holiday Inn Sunspree Resort Aruba Beach Resort...
# 231513   3577154.0                                         Oranjestad
# 6242     1148268.0                                          Ashkāsham
# 31830    7101703.0                                              Aytch
# ...            ...                                                ...
# 18077   11749707.0                                        Viper Shoal
# 6870     3163618.0                                West European Basin
# 16652    9408659.0                                     Western Europe
# 306685   6947193.0                              Western Mediterranean
# 43350    2205316.0                                White Island Canyon
#
#        country_code3      admin1
# 562301           ABW         NaN
# 410870           ABW         NaN
# 231513           ABW         NaN
# 6242             AFG  Badakhshan
# 31830            AFG  Badakhshan
# ...              ...         ...
# 18077            NaN         NaN
# 6870             NaN         NaN
# 16652            NaN         NaN
# 306685           NaN         NaN
# 43350            NaN         NaN
#
# [38421 rows x 4 columns]

# %%
geonames.to_csv(os.path.join(tweet_dir,"geonames_ones.csv"), index = False)

# %%
countries = pd.read_csv(os.path.join(tweet_dir,"Countries - Countries.csv"))

# %%
countries= countries.sort_values(by='Country')

# %%
countries.to_csv(os.path.join(tweet_dir,"Countries - Countries.csv"), index = False)
